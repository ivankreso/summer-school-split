# %% [markdown]
# # Semantic Segmentation
#
# In this exercise we will train an end-to-end convolutional neural network for semantic segmentation.
# The goal of semantic segmentation is to classify the image on the pixel level, for each pixel
# we want to determine the class of the object to which it belongs. This is different from image classification
# which classifies an image as a whole and doesn't tell us the location of the objects. This is why semantic segmentation goes into category of structured prediction problems. It answers on both the 'what' and 'where' questions while classfication tells us only 'what'.
#
# Input image | Target image
# -|-
# ![raw](assets/frankfurt_000000_014480.png) | ![raw](assets/frankfurt_000000_014480_labels.png)
# ![raw](assets/frankfurt_000001_005898.png) | ![raw](assets/frankfurt_000001_005898_labels.png)

# %% [markdown]
# ## 1. Cityscapes dataset
#
# [Cityscapes dataset](https://www.cityscapes-dataset.com/dataset-overview/) contains a diverse set of stereo video sequences recorded in street scenes from 50 different cities, with high quality pixel-level annotations. Dataset contains 2975 training and 500 validation images of size 2048x1024. The test set of 1000 images is evaluated on the server and benchmark is available [here](https://www.cityscapes-dataset.com/benchmarks/#scene-labeling-task). Here we will use downsampled images of size 384x160. The original dataset has 19 classes but we lowered that to 7 by uniting similar classes. This makes sense due to low visibility of very small objects in downsampled images. We also have ignore class which we need to ignore during training.
#
# * Download the prepared dataset [here]() and extract it to the current directory.
#
# ID | Class | Color
# -|-|-
# 0 | road | purple
# 1 | building | grey
# 2 | infrastructure | yellow
# 3 | nature | green
# 4 | sky | light blue
# 5 | person | red
# 6 | vehicle | dark blue
# 7 | ignore | black

# %% [markdown]
# ## 2. Building the graph
#
# Let's begin by importing all the modules and setting the fixed random seed.

# %%
# %matplotlib inline

import time
from os.path import join

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

import utils
from data import Dataset

tf.set_random_seed(31415)
tf.logging.set_verbosity(tf.logging.ERROR)

plt.axis('off')
plt.rcParams["figure.figsize"] = (15, 5)

# %% [markdown]
# ### Dataset
#
# The `Dataset` class implements an iterator which returns the next batch data in each iteration. Data is already normalized to have zero mean and unit variance. The iteration is terminated when we reach the end of the dataset (one epoch).

# %%
batch_size = 10
num_classes = Dataset.num_classes
# create the Dataset for training and validation
train_data = Dataset('train', batch_size)
val_data = Dataset('val', batch_size, shuffle=False)

print('Train shape:', train_data.x.shape)
print('Validation shape:', val_data.x.shape)

print('mean = ', train_data.x.mean((0,1,2)))
print('std = ', train_data.x.std((0,1,2)))
# Out:
# Train shape: (2975, 160, 384, 3)
# Validation shape: (500, 160, 384, 3)
# mean =  [-0.03841928 -0.04215339 -0.05894543]
# std =  [ 1.01808784  1.02022915  1.02732566]

# %% [markdown]
# ### Inputs
#
# First, we will create input placeholders for Tensorflow computational graph of the model. For a supervised learning model, we need to declare placeholders which will hold input images (x) and target labels (y) of the mini-batches as we feed them to the network.

# %%
# store the input image dimensions
height = train_data.height
width = train_data.width
channels = train_data.channels

# create placeholders for inputs
def build_inputs():
    with tf.name_scope('data'):
        x = tf.placeholder(tf.float32, shape=(None, height, width, channels), name='rgb_images')
        y = tf.placeholder(tf.int32, shape=(None, height, width), name='labels')
    return x, y

# %% [markdown]
# ### Model
#
# Now we can define the computational graph. Here we will heavily use [`tf.layers`](https://www.tensorflow.org/api_docs/python/tf/layers) high level API which handles `tf.Variable` creation for us. The main difference here compared to the classification model is that the network is going to be fully convolutional without any fully connected layers.

# %%
# helper function which applies conv2d + ReLU with filter size k
def conv(x, num_maps, k=3):
    x = tf.layers.conv2d(x, num_maps, k, padding='same')
    x = tf.nn.relu(x)
    return x

# helper function for 2x2 max pooling with stride=2
def pool(x):
    return tf.layers.max_pooling2d(x, pool_size=2, strides=2, padding='same')

# this functions takes the input placeholder and the number of classes, builds the model and returns the logits
def build_model(x, num_classes):
    input_size = x.get_shape().as_list()[1:3]
    block_sizes = [64, 64, 64, 64]
    x = conv(x, 32, k=3)
    for i, size in enumerate(block_sizes):
        with tf.name_scope('block'+str(i)):
            x = pool(x)
            x = conv(x, size)
            x = conv(x, size)
    print(x)
    with tf.name_scope('logits'):
        x = tf.layers.conv2d(x, num_classes, 1, padding='same')
        x = tf.image.resize_bilinear(x, input_size, name='upsample_logits')
    return x

# %% [markdown]
# ### Loss
#
# Now we are going to implement the `build_loss` funcion which will create operations for loss computation and return the final `tf.Tensor` holding the scalar loss value.
# Because segmentation is just classification on a pixel level we can again use the cross entropy loss function \\(L\\) between the target one-hot distribution \\( \mathbf{y} \\) and the predicted distribution from a softmax layer \\( \mathbf{s} \\). But compared to image clasificaion here we need to define the loss at each pixel. Below are the equations describing the loss for one example (one pixel in our case).
# $$
# L = - \sum_{i=1}^{C} y_i log(s_j(\mathbf{x})) \\
# s_i(\mathbf{x}) = \frac{e^{x_i}}{\sum_{j=1}^{C} e^{x_j}} \\
# $$

# %%
# this funcions takes logits and targets (y) and builds the loss subgraph
def build_loss(logits, y):
  with tf.name_scope('loss'):
    # vectorize the image
    y = tf.reshape(y, shape=[-1])
    logits = tf.reshape(logits, [-1, num_classes])
    
    # gather all labels with valid ID
    mask = y < num_classes
    y = tf.boolean_mask(y, mask)
    logits = tf.boolean_mask(logits, mask)

    y_one_hot = tf.one_hot(y, num_classes)
    xent = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_one_hot)

    xent = tf.reduce_mean(xent)
    tf.summary.scalar('cross_entropy', xent)
    return xent

# %% [markdown]
# ### Putting it all together
#
# Now we can use all the building blocks from above and construct the whole Tensorflow graph in just a couple of lines.

# %%
# create inputs
x, y = build_inputs()
# create model
logits = build_model(x, num_classes)
# create loss
loss = build_loss(logits, y)
# we are going to need argmax predictions for IoU
y_pred = tf.argmax(logits, axis=3, output_type=tf.int32)
# Out:
# Tensor("block3/Relu_1:0", shape=(?, 10, 24, 64), dtype=float32)

# %% [markdown]
# ## 3. Training the model

# %% [markdown]
# ### Validation
#
# We usually evaluate the semantic segmentation results with [Intersection over Union](https://en.wikipedia.org/wiki/Jaccard_index) measure (IoU aka Jaccard index). Note that accurracy we used on MNIST image classification problem is a bad measure in this case because semantic segmentation datasets are often heavily imbalanced. First we compute IoU for each class in one-vs-all fashion (shown below) and then take the mean IoU (mIoU) over all classes. By taking the mean we are treating all classes as equally important.
# $$
# IOU = \frac{TP}{TP + FN + FP}
# $$
#
# ![iou](assets/iou.png)

# %%
def validate(sess, data, x, y, y_pred, loss, draw_steps=0):
    print('\nValidation phase:')
    conf_mat = np.zeros((num_classes, num_classes), dtype=np.uint64) 
    for i, (x_np, y_np, names) in enumerate(data):
        start_time = time.time()
        loss_np, y_pred_np = sess.run([loss, y_pred],
          feed_dict={x: x_np, y: y_np})

        duration = time.time() - start_time
        batch_conf_mat = confusion_matrix(y_np.reshape(-1), y_pred_np.reshape(-1))
        batch_conf_mat = batch_conf_mat[:-1,:-1].astype(np.uint64)
        conf_mat += batch_conf_mat

        for j in range(min(draw_steps, batch_size)):
            img_pred = utils.colorize_labels(y_pred_np[j], Dataset.class_info)
            img_true = utils.colorize_labels(y_np[j], Dataset.class_info)
            img_raw = data.get_img(names[j])
            img = np.concatenate((img_raw, img_true, img_pred), axis=1)
            plt.imshow(img)
            plt.show()
            draw_steps -= 1

        if i % 10 == 0:
            string = 'batch %03d loss = %.2f  (%.1f images/sec)' % \
            (i, loss_np, x_np.shape[0] / duration)
            print(string)
    print(conf_mat)
    return utils.print_stats(conf_mat, 'Validation', Dataset.class_info)

# %% [markdown]
# ### Training

# %%
def train(sess, x, y, y_pred, loss, checkpoint_dir):
    num_epochs = 30
    batch_size = 10
    log_dir = 'local/logs'
    utils.clear_dir(log_dir)
    utils.clear_dir(checkpoint_dir)

    learning_rate = 1e-3
    decay_power = 1.0

    global_step = tf.Variable(0, trainable=False)
    decay_steps = num_epochs * train_data.num_batches

    lr = tf.train.polynomial_decay(learning_rate, global_step, decay_steps,
                                   end_learning_rate=0, power=decay_power)

    train_step = tf.train.AdamOptimizer(lr).minimize(loss, global_step=global_step)

    saver = tf.train.Saver()

    summary_all = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(join(log_dir, 'train'), sess.graph)

    tf.global_variables_initializer().run(session=sess)

    step = 0
    best_iou = 0
    best_epoch = 0
    exp_start_time = time.time()
    for epoch in range(1, num_epochs+1):
        # confusion_mat = np.zeros((num_classes, num_classes), dtype=np.uint64)
        print('\nTraining phase:')
        for x_np, y_np, names in train_data:
            start_time = time.time()
            loss_np, summary, _ = sess.run([loss, summary_all, train_step],
            feed_dict={x: x_np, y: y_np})
            train_writer.add_summary(summary, step)
            duration = time.time() - start_time
            # confusion_mat += batch_conf_mat.astype(np.uint64)
            if step % 20 == 0:
                string = '%s: epoch %d / %d, iter %05d, loss = %.2f  (%.1f images/sec)' % \
                (utils.get_expired_time(exp_start_time), epoch, num_epochs, step, loss_np, batch_size / duration)
                print(string)
            step += 1
        # utils.print_metrics(confusion_mat, 'Train') 
        iou = validate(sess, val_data, x, y, y_pred, loss, draw_steps=0)
        if iou > best_iou:
            best_iou, best_epoch = iou, epoch
            save_path = saver.save(sess, join(checkpoint_dir, 'model.ckpt'))
            print('Model saved in file: ', save_path)
        print('\nBest IoU = %.2f (epoch %d)' % (best_iou, best_epoch))

# %%
sess = tf.Session()
train(sess, x, y, y_pred, loss, 'local/checkpoint1')
# Out:
# /usr/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:95: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Training phase:
# 00:00:01: epoch 1 / 30, iter 00000, loss = 1.94  (13.4 images/sec)
# 00:00:01: epoch 1 / 30, iter 00020, loss = 0.99  (300.1 images/sec)
# 00:00:02: epoch 1 / 30, iter 00040, loss = 0.88  (302.4 images/sec)
# 00:00:03: epoch 1 / 30, iter 00060, loss = 0.96  (301.5 images/sec)
# 00:00:03: epoch 1 / 30, iter 00080, loss = 0.78  (302.1 images/sec)
# 00:00:04: epoch 1 / 30, iter 00100, loss = 0.87  (300.8 images/sec)
# 00:00:05: epoch 1 / 30, iter 00120, loss = 0.68  (299.4 images/sec)
# 00:00:05: epoch 1 / 30, iter 00140, loss = 0.93  (300.3 images/sec)
# 00:00:06: epoch 1 / 30, iter 00160, loss = 0.70  (303.6 images/sec)
# 00:00:07: epoch 1 / 30, iter 00180, loss = 0.71  (304.6 images/sec)
# 00:00:07: epoch 1 / 30, iter 00200, loss = 0.60  (299.7 images/sec)
# 00:00:08: epoch 1 / 30, iter 00220, loss = 0.59  (298.0 images/sec)
# 00:00:09: epoch 1 / 30, iter 00240, loss = 0.48  (301.4 images/sec)
# 00:00:09: epoch 1 / 30, iter 00260, loss = 0.50  (304.0 images/sec)
# 00:00:10: epoch 1 / 30, iter 00280, loss = 0.64  (301.1 images/sec)
#
# Validation phase:
# batch 000 loss = 0.54  (521.1 images/sec)
# batch 010 loss = 0.54  (721.4 images/sec)
# batch 020 loss = 0.65  (700.8 images/sec)
# batch 030 loss = 0.50  (692.9 images/sec)
# batch 040 loss = 0.53  (700.4 images/sec)
# [[11536045    78886        1    22348       70       31   123241]
#  [  245642  5440173      191   670187   291302        6   219355]
#  [  144107   501907       10   260752    18163       26    60980]
#  [  215419   549212      121  4565634    50119        3    86349]
#  [       6    42560        0    67722   796052        0      531]
#  [   78772   290892       18    46741      250       50    62265]
#  [  474082   560909        0   186214    14322       34  1320480]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 89.30 %
# 	building IoU accuracy = 61.19 %
# 	infrastructure IoU accuracy = 0.00 %
# 	nature IoU accuracy = 67.93 %
# 	sky IoU accuracy = 62.14 %
# 	person IoU accuracy = 0.01 %
# 	vehicle IoU accuracy = 42.48 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 46.15 %
# Validation pixel accuracy = 81.52 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 46.15 (epoch 1)
#
# Training phase:
# 00:00:24: epoch 2 / 30, iter 00300, loss = 0.51  (286.2 images/sec)
# 00:00:25: epoch 2 / 30, iter 00320, loss = 0.44  (302.4 images/sec)
# 00:00:26: epoch 2 / 30, iter 00340, loss = 0.42  (300.8 images/sec)
# 00:00:26: epoch 2 / 30, iter 00360, loss = 0.51  (299.8 images/sec)
# 00:00:27: epoch 2 / 30, iter 00380, loss = 0.46  (296.0 images/sec)
# 00:00:28: epoch 2 / 30, iter 00400, loss = 0.48  (300.6 images/sec)
# 00:00:28: epoch 2 / 30, iter 00420, loss = 0.55  (298.3 images/sec)
# 00:00:29: epoch 2 / 30, iter 00440, loss = 0.55  (302.5 images/sec)
# 00:00:30: epoch 2 / 30, iter 00460, loss = 0.54  (301.4 images/sec)
# 00:00:30: epoch 2 / 30, iter 00480, loss = 0.35  (300.5 images/sec)
# 00:00:31: epoch 2 / 30, iter 00500, loss = 0.37  (301.4 images/sec)
# 00:00:32: epoch 2 / 30, iter 00520, loss = 0.33  (298.0 images/sec)
# 00:00:32: epoch 2 / 30, iter 00540, loss = 0.39  (298.0 images/sec)
# 00:00:33: epoch 2 / 30, iter 00560, loss = 0.40  (319.6 images/sec)
# 00:00:34: epoch 2 / 30, iter 00580, loss = 0.43  (299.8 images/sec)
#
# Validation phase:
# batch 000 loss = 0.53  (714.5 images/sec)
# batch 010 loss = 0.56  (719.4 images/sec)
# batch 020 loss = 0.61  (713.1 images/sec)
# batch 030 loss = 0.43  (718.8 images/sec)
# batch 040 loss = 0.43  (719.5 images/sec)
# [[11415047   203953        2    10428      183    12460   118549]
#  [  137730  6348062        3   164101   100695    10935   105330]
#  [   92007   711830       57   121801    11340     9591    39319]
#  [  174040  1368107       44  3810294    47115     4540    62717]
#  [       4    87289        0    37749   781725        0      104]
#  [   52917   306578       17    15805       36    47237    56398]
#  [  250163   604327       30    46854     2310    23469  1628888]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 91.56 %
# 	building IoU accuracy = 62.55 %
# 	infrastructure IoU accuracy = 0.01 %
# 	nature IoU accuracy = 64.98 %
# 	sky IoU accuracy = 73.16 %
# 	person IoU accuracy = 8.75 %
# 	vehicle IoU accuracy = 55.43 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 50.92 %
# Validation pixel accuracy = 82.80 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 50.92 (epoch 2)
#
# Training phase:
# 00:00:47: epoch 3 / 30, iter 00600, loss = 0.46  (299.9 images/sec)
# 00:00:48: epoch 3 / 30, iter 00620, loss = 0.47  (303.0 images/sec)
# 00:00:49: epoch 3 / 30, iter 00640, loss = 0.42  (301.3 images/sec)
# 00:00:49: epoch 3 / 30, iter 00660, loss = 0.47  (303.8 images/sec)
# 00:00:50: epoch 3 / 30, iter 00680, loss = 0.41  (300.1 images/sec)
# 00:00:51: epoch 3 / 30, iter 00700, loss = 0.42  (298.5 images/sec)
# 00:00:51: epoch 3 / 30, iter 00720, loss = 0.44  (299.3 images/sec)
# 00:00:52: epoch 3 / 30, iter 00740, loss = 0.46  (296.1 images/sec)
# 00:00:53: epoch 3 / 30, iter 00760, loss = 0.51  (300.3 images/sec)
# 00:00:53: epoch 3 / 30, iter 00780, loss = 0.46  (300.6 images/sec)
# 00:00:54: epoch 3 / 30, iter 00800, loss = 0.38  (319.4 images/sec)
# 00:00:55: epoch 3 / 30, iter 00820, loss = 0.37  (299.4 images/sec)
# 00:00:55: epoch 3 / 30, iter 00840, loss = 0.41  (301.0 images/sec)
# 00:00:56: epoch 3 / 30, iter 00860, loss = 0.38  (295.2 images/sec)
# 00:00:57: epoch 3 / 30, iter 00880, loss = 0.39  (298.4 images/sec)
#
# Validation phase:
# batch 000 loss = 0.47  (690.2 images/sec)
# batch 010 loss = 0.50  (713.5 images/sec)
# batch 020 loss = 0.59  (683.7 images/sec)
# batch 030 loss = 0.37  (683.6 images/sec)
# batch 040 loss = 0.42  (685.0 images/sec)
# [[11407435    27724       60    17688       28    17216   290471]
#  [  182906  5325201      213   641339   172154    39431   505612]
#  [   92129   384799      419   257690    15758    28663   206487]
#  [  140623   329610      169  4710549    53344     5468   227094]
#  [       1    31232        0    47083   827537        0     1018]
#  [   37987   115272      226    36683       82    65164   223574]
#  [  181789   168459       74    78674     1093     7127  2118825]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 92.02 %
# 	building IoU accuracy = 67.20 %
# 	infrastructure IoU accuracy = 0.04 %
# 	nature IoU accuracy = 71.96 %
# 	sky IoU accuracy = 72.00 %
# 	person IoU accuracy = 11.30 %
# 	vehicle IoU accuracy = 52.83 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 52.48 %
# Validation pixel accuracy = 84.26 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 52.48 (epoch 3)
#
# Training phase:
# 00:01:11: epoch 4 / 30, iter 00900, loss = 0.45  (289.4 images/sec)
# 00:01:11: epoch 4 / 30, iter 00920, loss = 0.39  (298.6 images/sec)
# 00:01:12: epoch 4 / 30, iter 00940, loss = 0.34  (299.7 images/sec)
# 00:01:13: epoch 4 / 30, iter 00960, loss = 0.40  (303.9 images/sec)
# 00:01:13: epoch 4 / 30, iter 00980, loss = 0.44  (299.5 images/sec)
# 00:01:14: epoch 4 / 30, iter 01000, loss = 0.39  (297.3 images/sec)
# 00:01:15: epoch 4 / 30, iter 01020, loss = 0.52  (303.3 images/sec)
# 00:01:15: epoch 4 / 30, iter 01040, loss = 0.36  (301.0 images/sec)
# 00:01:16: epoch 4 / 30, iter 01060, loss = 0.35  (302.9 images/sec)
# 00:01:17: epoch 4 / 30, iter 01080, loss = 0.43  (300.7 images/sec)
# 00:01:17: epoch 4 / 30, iter 01100, loss = 0.35  (299.3 images/sec)
# 00:01:18: epoch 4 / 30, iter 01120, loss = 0.39  (302.8 images/sec)
# 00:01:19: epoch 4 / 30, iter 01140, loss = 0.42  (304.7 images/sec)
# 00:01:19: epoch 4 / 30, iter 01160, loss = 0.34  (302.5 images/sec)
# 00:01:20: epoch 4 / 30, iter 01180, loss = 0.35  (298.9 images/sec)
#
# Validation phase:
# batch 000 loss = 0.44  (721.7 images/sec)
# batch 010 loss = 0.43  (724.1 images/sec)
# batch 020 loss = 0.51  (719.0 images/sec)
# batch 030 loss = 0.31  (711.5 images/sec)
# batch 040 loss = 0.33  (710.9 images/sec)
# [[11316401    79597     1203    37187       96    38482   287656]
#  [  118974  6054903      948   301528    71544    59450   259509]
#  [   82321   539517     2137   187860    13113    45075   115922]
#  [   95769   629773     1946  4549385    40697    13971   135316]
#  [       0    61538       11    43878   800690        0      754]
#  [   33942   158688     1577    18630       24   151596   114531]
#  [   78256   243505      367    50948      875    34800  2147290]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 92.99 %
# 	building IoU accuracy = 70.57 %
# 	infrastructure IoU accuracy = 0.22 %
# 	nature IoU accuracy = 74.50 %
# 	sky IoU accuracy = 77.49 %
# 	person IoU accuracy = 22.60 %
# 	vehicle IoU accuracy = 61.89 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 57.18 %
# Validation pixel accuracy = 86.22 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 57.18 (epoch 4)
#
# Training phase:
# 00:01:34: epoch 5 / 30, iter 01200, loss = 0.41  (300.6 images/sec)
# 00:01:34: epoch 5 / 30, iter 01220, loss = 0.34  (297.8 images/sec)
# 00:01:35: epoch 5 / 30, iter 01240, loss = 0.34  (295.2 images/sec)
# 00:01:36: epoch 5 / 30, iter 01260, loss = 0.34  (304.2 images/sec)
# 00:01:36: epoch 5 / 30, iter 01280, loss = 0.31  (302.5 images/sec)
# 00:01:37: epoch 5 / 30, iter 01300, loss = 0.35  (297.1 images/sec)
# 00:01:38: epoch 5 / 30, iter 01320, loss = 0.37  (300.0 images/sec)
# 00:01:38: epoch 5 / 30, iter 01340, loss = 0.34  (301.2 images/sec)
# 00:01:39: epoch 5 / 30, iter 01360, loss = 0.40  (301.9 images/sec)
# 00:01:40: epoch 5 / 30, iter 01380, loss = 0.31  (300.9 images/sec)
# 00:01:40: epoch 5 / 30, iter 01400, loss = 0.28  (301.4 images/sec)
# 00:01:41: epoch 5 / 30, iter 01420, loss = 0.36  (295.6 images/sec)
# 00:01:42: epoch 5 / 30, iter 01440, loss = 0.32  (299.4 images/sec)
# 00:01:42: epoch 5 / 30, iter 01460, loss = 0.38  (300.4 images/sec)
# 00:01:43: epoch 5 / 30, iter 01480, loss = 0.37  (299.6 images/sec)
#
# Validation phase:
# batch 000 loss = 0.42  (693.5 images/sec)
# batch 010 loss = 0.44  (712.0 images/sec)
# batch 020 loss = 0.48  (682.0 images/sec)
# batch 030 loss = 0.33  (678.9 images/sec)
# batch 040 loss = 0.34  (698.9 images/sec)
# [[11403024   116342     8184    20582      104    34582   177804]
#  [  121527  6268919     6669   261550    37021    51489   119681]
#  [  101791   590621    13965   176996     9974    37985    54613]
#  [  157235   855785     9173  4325221    24122    14801    80520]
#  [       5    95959      549    61275   748554        5      524]
#  [   50472   170382     6433    21269        6   185972    44454]
#  [  154287   339209     6539    58863      503    72286  1924354]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 92.36 %
# 	building IoU accuracy = 69.38 %
# 	infrastructure IoU accuracy = 1.36 %
# 	nature IoU accuracy = 71.29 %
# 	sky IoU accuracy = 76.49 %
# 	person IoU accuracy = 26.95 %
# 	vehicle IoU accuracy = 63.43 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 57.32 %
# Validation pixel accuracy = 85.69 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 57.32 (epoch 5)
#
# Training phase:
# 00:01:57: epoch 6 / 30, iter 01500, loss = 0.41  (288.4 images/sec)
# 00:01:58: epoch 6 / 30, iter 01520, loss = 0.43  (300.5 images/sec)
# 00:01:58: epoch 6 / 30, iter 01540, loss = 0.43  (302.6 images/sec)
# 00:01:59: epoch 6 / 30, iter 01560, loss = 0.35  (299.5 images/sec)
# 00:02:00: epoch 6 / 30, iter 01580, loss = 0.35  (302.8 images/sec)
# 00:02:00: epoch 6 / 30, iter 01600, loss = 0.33  (298.1 images/sec)
# 00:02:01: epoch 6 / 30, iter 01620, loss = 0.36  (299.3 images/sec)
# 00:02:02: epoch 6 / 30, iter 01640, loss = 0.36  (301.1 images/sec)
# 00:02:02: epoch 6 / 30, iter 01660, loss = 0.35  (300.1 images/sec)
# 00:02:03: epoch 6 / 30, iter 01680, loss = 0.44  (301.1 images/sec)
# 00:02:04: epoch 6 / 30, iter 01700, loss = 0.32  (299.7 images/sec)
# 00:02:04: epoch 6 / 30, iter 01720, loss = 0.32  (302.6 images/sec)
# 00:02:05: epoch 6 / 30, iter 01740, loss = 0.30  (300.5 images/sec)
# 00:02:06: epoch 6 / 30, iter 01760, loss = 0.32  (298.0 images/sec)
# 00:02:06: epoch 6 / 30, iter 01780, loss = 0.33  (302.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.41  (713.3 images/sec)
# batch 010 loss = 0.42  (703.8 images/sec)
# batch 020 loss = 0.48  (717.6 images/sec)
# batch 030 loss = 0.29  (724.4 images/sec)
# batch 040 loss = 0.32  (719.9 images/sec)
# [[11389704    34595     6408    23617      102    35739   270457]
#  [  127909  5708414    18559   443913    67787    85072   415202]
#  [   85450   413799    22180   233027    13641    53924   163924]
#  [  126798   327541    14181  4798335    32104    15927   151971]
#  [       0    44145      935    53294   807292        0     1205]
#  [   34316    85195     2969    27568       23   173142   155775]
#  [  110312   120464     1733    62383      853    29918  2230378]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.01 %
# 	building IoU accuracy = 72.33 %
# 	infrastructure IoU accuracy = 2.15 %
# 	nature IoU accuracy = 76.04 %
# 	sky IoU accuracy = 79.04 %
# 	person IoU accuracy = 24.75 %
# 	vehicle IoU accuracy = 60.04 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 58.19 %
# Validation pixel accuracy = 86.59 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 58.19 (epoch 6)
#
# Training phase:
# 00:02:20: epoch 7 / 30, iter 01800, loss = 0.39  (301.7 images/sec)
# 00:02:21: epoch 7 / 30, iter 01820, loss = 0.33  (300.1 images/sec)
# 00:02:21: epoch 7 / 30, iter 01840, loss = 0.37  (303.6 images/sec)
# 00:02:22: epoch 7 / 30, iter 01860, loss = 0.35  (302.0 images/sec)
# 00:02:23: epoch 7 / 30, iter 01880, loss = 0.38  (302.0 images/sec)
# 00:02:23: epoch 7 / 30, iter 01900, loss = 0.34  (299.1 images/sec)
# 00:02:24: epoch 7 / 30, iter 01920, loss = 0.34  (299.9 images/sec)
# 00:02:25: epoch 7 / 30, iter 01940, loss = 0.32  (301.5 images/sec)
# 00:02:25: epoch 7 / 30, iter 01960, loss = 0.35  (302.7 images/sec)
# 00:02:26: epoch 7 / 30, iter 01980, loss = 0.35  (298.8 images/sec)
# 00:02:27: epoch 7 / 30, iter 02000, loss = 0.39  (297.3 images/sec)
# 00:02:27: epoch 7 / 30, iter 02020, loss = 0.30  (301.3 images/sec)
# 00:02:28: epoch 7 / 30, iter 02040, loss = 0.32  (296.9 images/sec)
# 00:02:29: epoch 7 / 30, iter 02060, loss = 0.34  (296.8 images/sec)
# 00:02:29: epoch 7 / 30, iter 02080, loss = 0.40  (297.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.40  (720.3 images/sec)
# batch 010 loss = 0.39  (709.3 images/sec)
# batch 020 loss = 0.47  (693.0 images/sec)
# batch 030 loss = 0.29  (687.1 images/sec)
# batch 040 loss = 0.32  (678.4 images/sec)
# [[11377451   117030     8005    31377      120    18742   207897]
#  [   99008  6113703     6169   378507    82108    27992   159369]
#  [   83385   550623    17378   223561    12808    18639    79551]
#  [  106595   438406     6701  4797626    25475     6779    85275]
#  [       1    43852      889    62006   799856        0      267]
#  [   45216   152960     6912    30006       34   137129   106731]
#  [   92476   232317     4039    67317      678    25211  2134003]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.35 %
# 	building IoU accuracy = 72.76 %
# 	infrastructure IoU accuracy = 1.71 %
# 	nature IoU accuracy = 76.64 %
# 	sky IoU accuracy = 77.80 %
# 	person IoU accuracy = 23.79 %
# 	vehicle IoU accuracy = 66.79 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 58.98 %
# Validation pixel accuracy = 87.44 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 58.98 (epoch 7)
#
# Training phase:
# 00:02:43: epoch 8 / 30, iter 02100, loss = 0.32  (295.9 images/sec)
# 00:02:44: epoch 8 / 30, iter 02120, loss = 0.30  (301.6 images/sec)
# 00:02:45: epoch 8 / 30, iter 02140, loss = 0.29  (301.8 images/sec)
# 00:02:45: epoch 8 / 30, iter 02160, loss = 0.25  (298.1 images/sec)
# 00:02:46: epoch 8 / 30, iter 02180, loss = 0.36  (297.0 images/sec)
# 00:02:47: epoch 8 / 30, iter 02200, loss = 0.33  (302.7 images/sec)
# 00:02:47: epoch 8 / 30, iter 02220, loss = 0.26  (301.1 images/sec)
# 00:02:48: epoch 8 / 30, iter 02240, loss = 0.32  (303.0 images/sec)
# 00:02:49: epoch 8 / 30, iter 02260, loss = 0.29  (301.9 images/sec)
# 00:02:49: epoch 8 / 30, iter 02280, loss = 0.37  (302.4 images/sec)
# 00:02:50: epoch 8 / 30, iter 02300, loss = 0.29  (295.4 images/sec)
# 00:02:51: epoch 8 / 30, iter 02320, loss = 0.34  (300.9 images/sec)
# 00:02:51: epoch 8 / 30, iter 02340, loss = 0.27  (299.9 images/sec)
# 00:02:52: epoch 8 / 30, iter 02360, loss = 0.35  (298.6 images/sec)
# 00:02:53: epoch 8 / 30, iter 02380, loss = 0.30  (301.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.39  (704.5 images/sec)
# batch 010 loss = 0.39  (713.0 images/sec)
# batch 020 loss = 0.45  (710.9 images/sec)
# batch 030 loss = 0.27  (711.7 images/sec)
# batch 040 loss = 0.31  (709.3 images/sec)
# [[11502835    42206     3156    35380      122    30852   146071]
#  [  148762  5890357     7910   373922   117391    68193   260321]
#  [  109083   470726    17794   225849    17056    42885   102552]
#  [  109289   365746     8618  4846768    39692    15424    81320]
#  [       1    30062      731    41418   833137        0     1522]
#  [   48968   112875     1930    28049      111   202636    84419]
#  [  151744   137879     1124    71322     1100    53552  2139320]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.30 %
# 	building IoU accuracy = 73.39 %
# 	infrastructure IoU accuracy = 1.76 %
# 	nature IoU accuracy = 77.64 %
# 	sky IoU accuracy = 76.98 %
# 	person IoU accuracy = 29.37 %
# 	vehicle IoU accuracy = 66.19 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 59.80 %
# Validation pixel accuracy = 87.63 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 59.80 (epoch 8)
#
# Training phase:
# 00:03:06: epoch 9 / 30, iter 02400, loss = 0.30  (300.2 images/sec)
# 00:03:07: epoch 9 / 30, iter 02420, loss = 0.32  (299.4 images/sec)
# 00:03:08: epoch 9 / 30, iter 02440, loss = 0.32  (301.3 images/sec)
# 00:03:08: epoch 9 / 30, iter 02460, loss = 0.34  (300.9 images/sec)
# 00:03:09: epoch 9 / 30, iter 02480, loss = 0.26  (300.4 images/sec)
# 00:03:10: epoch 9 / 30, iter 02500, loss = 0.29  (299.0 images/sec)
# 00:03:10: epoch 9 / 30, iter 02520, loss = 0.27  (302.8 images/sec)
# 00:03:11: epoch 9 / 30, iter 02540, loss = 0.30  (302.1 images/sec)
# 00:03:12: epoch 9 / 30, iter 02560, loss = 0.31  (301.9 images/sec)
# 00:03:12: epoch 9 / 30, iter 02580, loss = 0.32  (301.9 images/sec)
# 00:03:13: epoch 9 / 30, iter 02600, loss = 0.35  (299.1 images/sec)
# 00:03:14: epoch 9 / 30, iter 02620, loss = 0.42  (301.0 images/sec)
# 00:03:14: epoch 9 / 30, iter 02640, loss = 0.39  (301.0 images/sec)
# 00:03:15: epoch 9 / 30, iter 02660, loss = 0.32  (300.9 images/sec)
# 00:03:16: epoch 9 / 30, iter 02680, loss = 0.24  (295.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.36  (701.6 images/sec)
# batch 010 loss = 0.36  (725.3 images/sec)
# batch 020 loss = 0.42  (679.2 images/sec)
# batch 030 loss = 0.28  (685.7 images/sec)
# batch 040 loss = 0.30  (682.8 images/sec)
# [[11531396    26989    14518    27176      135    40298   120110]
#  [  158142  5922568    34860   378212    78367   109245   185462]
#  [  112137   428826    58500   230887    14520    65926    75149]
#  [  132770   367127    23814  4792636    37179    23921    89410]
#  [       2    37438     1774    43770   823390       11      486]
#  [   44863    69216     6315    27096       53   254173    77272]
#  [  127266   134554     8418    71077      773    63986  2149967]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.48 %
# 	building IoU accuracy = 74.68 %
# 	infrastructure IoU accuracy = 5.44 %
# 	nature IoU accuracy = 76.74 %
# 	sky IoU accuracy = 79.33 %
# 	person IoU accuracy = 32.49 %
# 	vehicle IoU accuracy = 69.27 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 61.63 %
# Validation pixel accuracy = 87.98 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 61.63 (epoch 9)
#
# Training phase:
# 00:03:30: epoch 10 / 30, iter 02700, loss = 0.31  (302.6 images/sec)
# 00:03:30: epoch 10 / 30, iter 02720, loss = 0.29  (291.7 images/sec)
# 00:03:31: epoch 10 / 30, iter 02740, loss = 0.33  (299.6 images/sec)
# 00:03:32: epoch 10 / 30, iter 02760, loss = 0.26  (301.8 images/sec)
# 00:03:32: epoch 10 / 30, iter 02780, loss = 0.27  (320.0 images/sec)
# 00:03:33: epoch 10 / 30, iter 02800, loss = 0.30  (301.9 images/sec)
# 00:03:34: epoch 10 / 30, iter 02820, loss = 0.27  (295.6 images/sec)
# 00:03:34: epoch 10 / 30, iter 02840, loss = 0.33  (302.0 images/sec)
# 00:03:35: epoch 10 / 30, iter 02860, loss = 0.27  (302.3 images/sec)
# 00:03:36: epoch 10 / 30, iter 02880, loss = 0.26  (304.4 images/sec)
# 00:03:36: epoch 10 / 30, iter 02900, loss = 0.30  (291.0 images/sec)
# 00:03:37: epoch 10 / 30, iter 02920, loss = 0.24  (301.8 images/sec)
# 00:03:38: epoch 10 / 30, iter 02940, loss = 0.26  (296.6 images/sec)
# 00:03:38: epoch 10 / 30, iter 02960, loss = 0.37  (299.9 images/sec)
#
# Validation phase:
# batch 000 loss = 0.37  (722.0 images/sec)
# batch 010 loss = 0.40  (715.7 images/sec)
# batch 020 loss = 0.44  (710.8 images/sec)
# batch 030 loss = 0.29  (717.1 images/sec)
# batch 040 loss = 0.31  (715.8 images/sec)
# [[11494784    64916     6895    34109       76    38776   121066]
#  [  133478  6262448     6279   256686    51586    30633   125746]
#  [   98876   557539    22727   188477    12948    37842    67536]
#  [  127814   599189    10925  4635041    25807     9702    58379]
#  [       1    62390      747    47902   795522        1      308]
#  [   41915   151572     2632    22623       68   177493    82685]
#  [  136827   245805     3067    61088      632    34668  2073954]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.46 %
# 	building IoU accuracy = 73.26 %
# 	infrastructure IoU accuracy = 2.24 %
# 	nature IoU accuracy = 76.26 %
# 	sky IoU accuracy = 79.71 %
# 	person IoU accuracy = 28.15 %
# 	vehicle IoU accuracy = 68.86 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 60.28 %
# Validation pixel accuracy = 87.73 %
#
# Best IoU = 61.63 (epoch 9)
#
# Training phase:
# 00:03:52: epoch 11 / 30, iter 02980, loss = 0.32  (299.1 images/sec)
# 00:03:52: epoch 11 / 30, iter 03000, loss = 0.30  (302.9 images/sec)
# 00:03:53: epoch 11 / 30, iter 03020, loss = 0.31  (301.2 images/sec)
# 00:03:54: epoch 11 / 30, iter 03040, loss = 0.27  (300.4 images/sec)
# 00:03:54: epoch 11 / 30, iter 03060, loss = 0.33  (296.0 images/sec)
# 00:03:55: epoch 11 / 30, iter 03080, loss = 0.28  (302.3 images/sec)
# 00:03:56: epoch 11 / 30, iter 03100, loss = 0.32  (301.8 images/sec)
# 00:03:56: epoch 11 / 30, iter 03120, loss = 0.35  (293.4 images/sec)
# 00:03:57: epoch 11 / 30, iter 03140, loss = 0.31  (294.2 images/sec)
# 00:03:58: epoch 11 / 30, iter 03160, loss = 0.27  (300.9 images/sec)
# 00:03:58: epoch 11 / 30, iter 03180, loss = 0.27  (296.2 images/sec)
# 00:03:59: epoch 11 / 30, iter 03200, loss = 0.31  (300.1 images/sec)
# 00:04:00: epoch 11 / 30, iter 03220, loss = 0.33  (301.9 images/sec)
# 00:04:00: epoch 11 / 30, iter 03240, loss = 0.31  (302.7 images/sec)
# 00:04:01: epoch 11 / 30, iter 03260, loss = 0.22  (295.6 images/sec)
#
# Validation phase:
# batch 000 loss = 0.36  (709.0 images/sec)
# batch 010 loss = 0.35  (720.2 images/sec)
# batch 020 loss = 0.41  (681.7 images/sec)
# batch 030 loss = 0.26  (663.7 images/sec)
# batch 040 loss = 0.27  (690.6 images/sec)
# [[11446959    48909    11672    42085      140    41358   169499]
#  [  118925  6125268    26943   332068    68260    68959   126433]
#  [   94322   485363    60217   219829    13633    49573    63008]
#  [   86459   379751    24410  4862462    37670    16335    59770]
#  [       0    41543     2009    40575   822511        0      233]
#  [   39635   101860     4604    27534       61   246828    58466]
#  [   79786   182543     6767    66771      675    68877  2150622]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.98 %
# 	building IoU accuracy = 75.56 %
# 	infrastructure IoU accuracy = 5.67 %
# 	nature IoU accuracy = 78.48 %
# 	sky IoU accuracy = 80.06 %
# 	person IoU accuracy = 34.09 %
# 	vehicle IoU accuracy = 70.90 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 62.68 %
# Validation pixel accuracy = 88.60 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 62.68 (epoch 11)
#
# Training phase:
# 00:04:15: epoch 12 / 30, iter 03280, loss = 0.30  (281.7 images/sec)
# 00:04:15: epoch 12 / 30, iter 03300, loss = 0.27  (296.9 images/sec)
# 00:04:16: epoch 12 / 30, iter 03320, loss = 0.29  (302.3 images/sec)
# 00:04:17: epoch 12 / 30, iter 03340, loss = 0.28  (301.8 images/sec)
# 00:04:17: epoch 12 / 30, iter 03360, loss = 0.29  (299.1 images/sec)
# 00:04:18: epoch 12 / 30, iter 03380, loss = 0.32  (299.1 images/sec)
# 00:04:19: epoch 12 / 30, iter 03400, loss = 0.43  (302.4 images/sec)
# 00:04:19: epoch 12 / 30, iter 03420, loss = 0.25  (298.1 images/sec)
# 00:04:20: epoch 12 / 30, iter 03440, loss = 0.30  (303.5 images/sec)
# 00:04:21: epoch 12 / 30, iter 03460, loss = 0.27  (302.1 images/sec)
# 00:04:21: epoch 12 / 30, iter 03480, loss = 0.29  (301.0 images/sec)
# 00:04:22: epoch 12 / 30, iter 03500, loss = 0.28  (303.7 images/sec)
# 00:04:23: epoch 12 / 30, iter 03520, loss = 0.27  (320.5 images/sec)
# 00:04:23: epoch 12 / 30, iter 03540, loss = 0.28  (302.6 images/sec)
# 00:04:24: epoch 12 / 30, iter 03560, loss = 0.28  (304.3 images/sec)
#
# Validation phase:
# batch 000 loss = 0.35  (729.9 images/sec)
# batch 010 loss = 0.35  (716.6 images/sec)
# batch 020 loss = 0.41  (717.8 images/sec)
# batch 030 loss = 0.26  (704.7 images/sec)
# batch 040 loss = 0.29  (717.9 images/sec)
# [[11480559    46974    26108    40448       68    17700   148765]
#  [  114264  6016142    43034   420260    46095    23383   203678]
#  [   86964   447016    85975   252577    13449    14642    85322]
#  [   92009   285669    23735  4969089    34177     4041    58137]
#  [       0    50394     1826    41825   812267        0      559]
#  [   44548   122419    12988    40640       55   149459   108879]
#  [   95479   131499    11260    81039      582    17080  2219102]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.15 %
# 	building IoU accuracy = 75.67 %
# 	infrastructure IoU accuracy = 7.78 %
# 	nature IoU accuracy = 78.33 %
# 	sky IoU accuracy = 81.12 %
# 	person IoU accuracy = 26.89 %
# 	vehicle IoU accuracy = 70.19 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 62.02 %
# Validation pixel accuracy = 88.67 %
#
# Best IoU = 62.68 (epoch 11)
#
# Training phase:
# 00:04:38: epoch 13 / 30, iter 03580, loss = 0.34  (299.5 images/sec)
# 00:04:38: epoch 13 / 30, iter 03600, loss = 0.29  (299.1 images/sec)
# 00:04:39: epoch 13 / 30, iter 03620, loss = 0.26  (302.1 images/sec)
# 00:04:40: epoch 13 / 30, iter 03640, loss = 0.26  (297.8 images/sec)
# 00:04:40: epoch 13 / 30, iter 03660, loss = 0.25  (301.9 images/sec)
# 00:04:41: epoch 13 / 30, iter 03680, loss = 0.27  (301.9 images/sec)
# 00:04:42: epoch 13 / 30, iter 03700, loss = 0.32  (302.9 images/sec)
# 00:04:42: epoch 13 / 30, iter 03720, loss = 0.26  (294.3 images/sec)
# 00:04:43: epoch 13 / 30, iter 03740, loss = 0.25  (293.0 images/sec)
# 00:04:44: epoch 13 / 30, iter 03760, loss = 0.27  (297.7 images/sec)
# 00:04:44: epoch 13 / 30, iter 03780, loss = 0.28  (301.7 images/sec)
# 00:04:45: epoch 13 / 30, iter 03800, loss = 0.27  (299.2 images/sec)
# 00:04:46: epoch 13 / 30, iter 03820, loss = 0.26  (303.7 images/sec)
# 00:04:46: epoch 13 / 30, iter 03840, loss = 0.31  (301.5 images/sec)
# 00:04:47: epoch 13 / 30, iter 03860, loss = 0.30  (299.7 images/sec)
#
# Validation phase:
# batch 000 loss = 0.35  (718.1 images/sec)
# batch 010 loss = 0.36  (723.8 images/sec)
# batch 020 loss = 0.42  (685.4 images/sec)
# batch 030 loss = 0.25  (683.8 images/sec)
# batch 040 loss = 0.28  (693.4 images/sec)
# [[11522848    39224     6628    36164       92    35598   120068]
#  [  135395  5979978    39726   350400    63713    94316   203328]
#  [  117851   430696    61858   221598    12753    62817    78372]
#  [   96807   344196    22451  4861680    37031    22378    82314]
#  [       1    40249     3334    40752   821904        3      628]
#  [   50872    86007     2552    23436       68   257956    58097]
#  [  126908   141172     4136    50855      796    74631  2157543]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.77 %
# 	building IoU accuracy = 75.23 %
# 	infrastructure IoU accuracy = 5.81 %
# 	nature IoU accuracy = 78.54 %
# 	sky IoU accuracy = 80.47 %
# 	person IoU accuracy = 33.56 %
# 	vehicle IoU accuracy = 69.62 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 62.43 %
# Validation pixel accuracy = 88.43 %
#
# Best IoU = 62.68 (epoch 11)
#
# Training phase:
# 00:05:00: epoch 14 / 30, iter 03880, loss = 0.30  (289.6 images/sec)
# 00:05:01: epoch 14 / 30, iter 03900, loss = 0.27  (297.8 images/sec)
# 00:05:02: epoch 14 / 30, iter 03920, loss = 0.30  (300.1 images/sec)
# 00:05:02: epoch 14 / 30, iter 03940, loss = 0.30  (302.3 images/sec)
# 00:05:03: epoch 14 / 30, iter 03960, loss = 0.25  (300.6 images/sec)
# 00:05:04: epoch 14 / 30, iter 03980, loss = 0.32  (297.9 images/sec)
# 00:05:04: epoch 14 / 30, iter 04000, loss = 0.22  (298.4 images/sec)
# 00:05:05: epoch 14 / 30, iter 04020, loss = 0.21  (300.6 images/sec)
# 00:05:06: epoch 14 / 30, iter 04040, loss = 0.30  (302.2 images/sec)
# 00:05:06: epoch 14 / 30, iter 04060, loss = 0.25  (299.7 images/sec)
# 00:05:07: epoch 14 / 30, iter 04080, loss = 0.21  (299.3 images/sec)
# 00:05:08: epoch 14 / 30, iter 04100, loss = 0.23  (298.6 images/sec)
# 00:05:08: epoch 14 / 30, iter 04120, loss = 0.23  (298.4 images/sec)
# 00:05:09: epoch 14 / 30, iter 04140, loss = 0.24  (300.0 images/sec)
# 00:05:10: epoch 14 / 30, iter 04160, loss = 0.25  (299.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.36  (712.6 images/sec)
# batch 010 loss = 0.36  (719.5 images/sec)
# batch 020 loss = 0.40  (717.3 images/sec)
# batch 030 loss = 0.26  (724.5 images/sec)
# batch 040 loss = 0.28  (723.3 images/sec)
# [[11460215    41926    52951    30577      175    37169   137609]
#  [  102281  6059369    73568   279270   119877    54665   177826]
#  [   76196   453884   144683   200737    17111    28224    65110]
#  [  106079   388263    58329  4769042    58850    12219    74075]
#  [       0    25899     1512    25855   853417        4      184]
#  [   38414   105060    21020    26979       72   230168    57275]
#  [   85159   148770    24140    55269     1085    54158  2187460]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.18 %
# 	building IoU accuracy = 75.45 %
# 	infrastructure IoU accuracy = 11.88 %
# 	nature IoU accuracy = 78.37 %
# 	sky IoU accuracy = 77.30 %
# 	person IoU accuracy = 34.59 %
# 	vehicle IoU accuracy = 71.30 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 63.30 %
# Validation pixel accuracy = 88.57 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 63.30 (epoch 14)
#
# Training phase:
# 00:05:24: epoch 15 / 30, iter 04180, loss = 0.30  (301.6 images/sec)
# 00:05:24: epoch 15 / 30, iter 04200, loss = 0.37  (302.4 images/sec)
# 00:05:25: epoch 15 / 30, iter 04220, loss = 0.26  (302.9 images/sec)
# 00:05:26: epoch 15 / 30, iter 04240, loss = 0.22  (301.9 images/sec)
# 00:05:26: epoch 15 / 30, iter 04260, loss = 0.24  (299.4 images/sec)
# 00:05:27: epoch 15 / 30, iter 04280, loss = 0.27  (304.0 images/sec)
# 00:05:28: epoch 15 / 30, iter 04300, loss = 0.33  (303.3 images/sec)
# 00:05:28: epoch 15 / 30, iter 04320, loss = 0.28  (298.5 images/sec)
# 00:05:29: epoch 15 / 30, iter 04340, loss = 0.30  (300.9 images/sec)
# 00:05:30: epoch 15 / 30, iter 04360, loss = 0.31  (295.9 images/sec)
# 00:05:30: epoch 15 / 30, iter 04380, loss = 0.27  (298.7 images/sec)
# 00:05:31: epoch 15 / 30, iter 04400, loss = 0.26  (292.4 images/sec)
# 00:05:32: epoch 15 / 30, iter 04420, loss = 0.30  (301.0 images/sec)
# 00:05:32: epoch 15 / 30, iter 04440, loss = 0.27  (301.3 images/sec)
# 00:05:33: epoch 15 / 30, iter 04460, loss = 0.27  (301.8 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (700.1 images/sec)
# batch 010 loss = 0.33  (725.3 images/sec)
# batch 020 loss = 0.41  (689.0 images/sec)
# batch 030 loss = 0.25  (684.6 images/sec)
# batch 040 loss = 0.27  (678.5 images/sec)
# [[11490699    43899    22016    54924       66    36584   112434]
#  [  104874  6006899    69972   403483    54760    63402   163466]
#  [   93412   408449   122300   244968    13027    38223    65566]
#  [   76870   272702    31963  4984069    26993    15327    58933]
#  [       0    43221     3066    50736   809216        0      632]
#  [   43029    87406     9145    32697       73   252560    54078]
#  [  104111   142993    11739    83063      767    58533  2154835]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.32 %
# 	building IoU accuracy = 76.37 %
# 	infrastructure IoU accuracy = 10.79 %
# 	nature IoU accuracy = 78.65 %
# 	sky IoU accuracy = 80.72 %
# 	person IoU accuracy = 36.55 %
# 	vehicle IoU accuracy = 71.56 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 64.14 %
# Validation pixel accuracy = 88.97 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 64.14 (epoch 15)
#
# Training phase:
# 00:05:47: epoch 16 / 30, iter 04480, loss = 0.28  (290.4 images/sec)
# 00:05:47: epoch 16 / 30, iter 04500, loss = 0.25  (299.8 images/sec)
# 00:05:48: epoch 16 / 30, iter 04520, loss = 0.28  (300.6 images/sec)
# 00:05:49: epoch 16 / 30, iter 04540, loss = 0.30  (299.2 images/sec)
# 00:05:49: epoch 16 / 30, iter 04560, loss = 0.27  (300.6 images/sec)
# 00:05:50: epoch 16 / 30, iter 04580, loss = 0.23  (301.5 images/sec)
# 00:05:51: epoch 16 / 30, iter 04600, loss = 0.26  (302.9 images/sec)
# 00:05:51: epoch 16 / 30, iter 04620, loss = 0.26  (302.3 images/sec)
# 00:05:52: epoch 16 / 30, iter 04640, loss = 0.29  (301.0 images/sec)
# 00:05:53: epoch 16 / 30, iter 04660, loss = 0.21  (299.8 images/sec)
# 00:05:53: epoch 16 / 30, iter 04680, loss = 0.30  (302.9 images/sec)
# 00:05:54: epoch 16 / 30, iter 04700, loss = 0.31  (302.5 images/sec)
# 00:05:55: epoch 16 / 30, iter 04720, loss = 0.23  (296.7 images/sec)
# 00:05:55: epoch 16 / 30, iter 04740, loss = 0.27  (301.9 images/sec)
# 00:05:56: epoch 16 / 30, iter 04760, loss = 0.24  (301.2 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (719.0 images/sec)
# batch 010 loss = 0.34  (710.3 images/sec)
# batch 020 loss = 0.41  (710.6 images/sec)
# batch 030 loss = 0.25  (717.4 images/sec)
# batch 040 loss = 0.28  (705.6 images/sec)
# [[11528082    34530    28065    37836      104    24237   107768]
#  [  110473  6040165    63624   396457    64733    33089   158315]
#  [   93805   427786   121729   239080    13894    19604    70047]
#  [   94005   274686    39212  4955636    38771     6884    57663]
#  [       2    38317     1775    38199   828371        0      207]
#  [   48724   101970    15383    35030       72   195744    82065]
#  [  121022   135730    16296    70833      915    29023  2182222]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.27 %
# 	building IoU accuracy = 76.65 %
# 	infrastructure IoU accuracy = 10.58 %
# 	nature IoU accuracy = 78.86 %
# 	sky IoU accuracy = 80.79 %
# 	person IoU accuracy = 33.07 %
# 	vehicle IoU accuracy = 71.97 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 63.74 %
# Validation pixel accuracy = 89.08 %
#
# Best IoU = 64.14 (epoch 15)
#
# Training phase:
# 00:06:09: epoch 17 / 30, iter 04780, loss = 0.25  (315.1 images/sec)
# 00:06:10: epoch 17 / 30, iter 04800, loss = 0.26  (303.6 images/sec)
# 00:06:11: epoch 17 / 30, iter 04820, loss = 0.32  (301.2 images/sec)
# 00:06:11: epoch 17 / 30, iter 04840, loss = 0.25  (302.8 images/sec)
# 00:06:12: epoch 17 / 30, iter 04860, loss = 0.21  (301.3 images/sec)
# 00:06:13: epoch 17 / 30, iter 04880, loss = 0.27  (301.5 images/sec)
# 00:06:13: epoch 17 / 30, iter 04900, loss = 0.28  (301.8 images/sec)
# 00:06:14: epoch 17 / 30, iter 04920, loss = 0.24  (302.9 images/sec)
# 00:06:15: epoch 17 / 30, iter 04940, loss = 0.26  (299.4 images/sec)
# 00:06:15: epoch 17 / 30, iter 04960, loss = 0.27  (302.4 images/sec)
# 00:06:16: epoch 17 / 30, iter 04980, loss = 0.31  (299.2 images/sec)
# 00:06:17: epoch 17 / 30, iter 05000, loss = 0.29  (301.6 images/sec)
# 00:06:17: epoch 17 / 30, iter 05020, loss = 0.29  (297.2 images/sec)
# 00:06:18: epoch 17 / 30, iter 05040, loss = 0.27  (301.8 images/sec)
# 00:06:19: epoch 17 / 30, iter 05060, loss = 0.27  (298.3 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (722.8 images/sec)
# batch 010 loss = 0.33  (776.1 images/sec)
# batch 020 loss = 0.40  (685.2 images/sec)
# batch 030 loss = 0.25  (680.6 images/sec)
# batch 040 loss = 0.27  (683.5 images/sec)
# [[11461739    30214    27712    37808      133    61574   141442]
#  [  116400  5927222    78310   361275    65719   104759   213171]
#  [   86146   386335   131727   225948    13770    62710    79309]
#  [   91389   275174    38442  4924448    33436    22742    81226]
#  [       0    37944     2739    43325   822334        8      521]
#  [   29527    60724     7896    24819       58   296498    59466]
#  [   79542    99909    12877    59392      693    72069  2231559]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.23 %
# 	building IoU accuracy = 76.41 %
# 	infrastructure IoU accuracy = 11.42 %
# 	nature IoU accuracy = 79.18 %
# 	sky IoU accuracy = 80.57 %
# 	person IoU accuracy = 36.93 %
# 	vehicle IoU accuracy = 71.27 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 64.29 %
# Validation pixel accuracy = 88.88 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 64.29 (epoch 17)
#
# Training phase:
# 00:06:33: epoch 18 / 30, iter 05080, loss = 0.21  (301.1 images/sec)
# 00:06:33: epoch 18 / 30, iter 05100, loss = 0.25  (300.1 images/sec)
# 00:06:34: epoch 18 / 30, iter 05120, loss = 0.27  (298.7 images/sec)
# 00:06:35: epoch 18 / 30, iter 05140, loss = 0.24  (300.8 images/sec)
# 00:06:35: epoch 18 / 30, iter 05160, loss = 0.26  (303.7 images/sec)
# 00:06:36: epoch 18 / 30, iter 05180, loss = 0.31  (298.8 images/sec)
# 00:06:37: epoch 18 / 30, iter 05200, loss = 0.27  (302.6 images/sec)
# 00:06:37: epoch 18 / 30, iter 05220, loss = 0.26  (301.3 images/sec)
# 00:06:38: epoch 18 / 30, iter 05240, loss = 0.22  (302.1 images/sec)
# 00:06:39: epoch 18 / 30, iter 05260, loss = 0.29  (302.6 images/sec)
# 00:06:39: epoch 18 / 30, iter 05280, loss = 0.26  (298.8 images/sec)
# 00:06:40: epoch 18 / 30, iter 05300, loss = 0.30  (298.2 images/sec)
# 00:06:41: epoch 18 / 30, iter 05320, loss = 0.26  (303.3 images/sec)
# 00:06:41: epoch 18 / 30, iter 05340, loss = 0.22  (300.5 images/sec)
# 00:06:42: epoch 18 / 30, iter 05360, loss = 0.27  (301.2 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (711.6 images/sec)
# batch 010 loss = 0.33  (719.1 images/sec)
# batch 020 loss = 0.41  (710.1 images/sec)
# batch 030 loss = 0.26  (699.9 images/sec)
# batch 040 loss = 0.27  (699.0 images/sec)
# [[11492029    56876    27944    48078      103    32030   103562]
#  [   97709  6159690    59095   372602    56577    43162    78021]
#  [   89941   453017   129239   237517    12909    24371    38951]
#  [   75603   321543    33637  4957924    35160    10134    32856]
#  [       0    39674     3203    40442   823377        0      175]
#  [   45764   108635    14688    33175       63   232931    43732]
#  [  107036   206959    25874    92646      757    53846  2068923]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.38 %
# 	building IoU accuracy = 76.48 %
# 	infrastructure IoU accuracy = 11.23 %
# 	nature IoU accuracy = 78.81 %
# 	sky IoU accuracy = 81.33 %
# 	person IoU accuracy = 36.25 %
# 	vehicle IoU accuracy = 72.51 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 64.43 %
# Validation pixel accuracy = 89.12 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 64.43 (epoch 18)
#
# Training phase:
# 00:06:56: epoch 19 / 30, iter 05380, loss = 0.24  (302.9 images/sec)
# 00:06:57: epoch 19 / 30, iter 05400, loss = 0.23  (299.8 images/sec)
# 00:06:57: epoch 19 / 30, iter 05420, loss = 0.24  (298.8 images/sec)
# 00:06:58: epoch 19 / 30, iter 05440, loss = 0.23  (302.5 images/sec)
# 00:06:59: epoch 19 / 30, iter 05460, loss = 0.23  (300.2 images/sec)
# 00:06:59: epoch 19 / 30, iter 05480, loss = 0.30  (298.2 images/sec)
# 00:07:00: epoch 19 / 30, iter 05500, loss = 0.23  (294.3 images/sec)
# 00:07:01: epoch 19 / 30, iter 05520, loss = 0.20  (301.0 images/sec)
# 00:07:01: epoch 19 / 30, iter 05540, loss = 0.31  (299.4 images/sec)
# 00:07:02: epoch 19 / 30, iter 05560, loss = 0.29  (298.3 images/sec)
# 00:07:03: epoch 19 / 30, iter 05580, loss = 0.27  (298.2 images/sec)
# 00:07:03: epoch 19 / 30, iter 05600, loss = 0.25  (302.6 images/sec)
# 00:07:04: epoch 19 / 30, iter 05620, loss = 0.30  (298.4 images/sec)
# 00:07:05: epoch 19 / 30, iter 05640, loss = 0.26  (300.0 images/sec)
# 00:07:05: epoch 19 / 30, iter 05660, loss = 0.25  (301.6 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (717.4 images/sec)
# batch 010 loss = 0.35  (713.8 images/sec)
# batch 020 loss = 0.40  (690.1 images/sec)
# batch 030 loss = 0.25  (684.5 images/sec)
# batch 040 loss = 0.26  (690.5 images/sec)
# [[11477632    75016    19568    31703       78    46840   109785]
#  [   77902  6347691    29205   239252    43604    38092    91110]
#  [   86086   519708    88367   198964    13299    28236    51285]
#  [   95087   438194    27331  4809531    34330    11325    51059]
#  [       0    54318     1190    37065   814004        0      294]
#  [   36199   125727     7223    22981       62   240844    45952]
#  [   98103   205541    11062    53382      598    55454  2131901]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.44 %
# 	building IoU accuracy = 76.61 %
# 	infrastructure IoU accuracy = 8.17 %
# 	nature IoU accuracy = 79.49 %
# 	sky IoU accuracy = 81.49 %
# 	person IoU accuracy = 36.55 %
# 	vehicle IoU accuracy = 73.37 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 64.30 %
# Validation pixel accuracy = 89.28 %
#
# Best IoU = 64.43 (epoch 18)
#
# Training phase:
# 00:07:19: epoch 20 / 30, iter 05680, loss = 0.22  (301.7 images/sec)
# 00:07:19: epoch 20 / 30, iter 05700, loss = 0.23  (301.1 images/sec)
# 00:07:20: epoch 20 / 30, iter 05720, loss = 0.24  (303.9 images/sec)
# 00:07:21: epoch 20 / 30, iter 05740, loss = 0.27  (296.0 images/sec)
# 00:07:21: epoch 20 / 30, iter 05760, loss = 0.23  (301.8 images/sec)
# 00:07:22: epoch 20 / 30, iter 05780, loss = 0.24  (301.2 images/sec)
# 00:07:23: epoch 20 / 30, iter 05800, loss = 0.25  (300.8 images/sec)
# 00:07:23: epoch 20 / 30, iter 05820, loss = 0.27  (301.9 images/sec)
# 00:07:24: epoch 20 / 30, iter 05840, loss = 0.19  (295.7 images/sec)
# 00:07:25: epoch 20 / 30, iter 05860, loss = 0.27  (301.1 images/sec)
# 00:07:25: epoch 20 / 30, iter 05880, loss = 0.22  (299.2 images/sec)
# 00:07:26: epoch 20 / 30, iter 05900, loss = 0.23  (302.7 images/sec)
# 00:07:27: epoch 20 / 30, iter 05920, loss = 0.29  (297.5 images/sec)
# 00:07:27: epoch 20 / 30, iter 05940, loss = 0.23  (301.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (716.1 images/sec)
# batch 010 loss = 0.33  (715.2 images/sec)
# batch 020 loss = 0.39  (707.9 images/sec)
# batch 030 loss = 0.24  (718.5 images/sec)
# batch 040 loss = 0.26  (709.6 images/sec)
# [[11492300    52004    19619    42489       87    32794   121329]
#  [   88828  6212998    41102   311941    53622    45511   112854]
#  [   88530   459195   103786   224584    13003    32199    64648]
#  [   79731   342272    25990  4919694    33577    12158    53435]
#  [       0    40513     3262    41744   821199        0      153]
#  [   45447   103523     5188    29466       91   230529    64744]
#  [   95104   162782     8363    65002      939    43584  2180267]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.52 %
# 	building IoU accuracy = 77.40 %
# 	infrastructure IoU accuracy = 9.53 %
# 	nature IoU accuracy = 79.58 %
# 	sky IoU accuracy = 81.45 %
# 	person IoU accuracy = 35.73 %
# 	vehicle IoU accuracy = 73.33 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 64.51 %
# Validation pixel accuracy = 89.45 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 64.51 (epoch 20)
#
# Training phase:
# 00:07:41: epoch 21 / 30, iter 05960, loss = 0.24  (297.6 images/sec)
# 00:07:42: epoch 21 / 30, iter 05980, loss = 0.24  (297.6 images/sec)
# 00:07:43: epoch 21 / 30, iter 06000, loss = 0.23  (294.6 images/sec)
# 00:07:43: epoch 21 / 30, iter 06020, loss = 0.25  (297.9 images/sec)
# 00:07:44: epoch 21 / 30, iter 06040, loss = 0.23  (302.7 images/sec)
# 00:07:45: epoch 21 / 30, iter 06060, loss = 0.22  (303.3 images/sec)
# 00:07:45: epoch 21 / 30, iter 06080, loss = 0.26  (302.1 images/sec)
# 00:07:46: epoch 21 / 30, iter 06100, loss = 0.33  (295.4 images/sec)
# 00:07:47: epoch 21 / 30, iter 06120, loss = 0.29  (301.2 images/sec)
# 00:07:47: epoch 21 / 30, iter 06140, loss = 0.24  (313.6 images/sec)
# 00:07:48: epoch 21 / 30, iter 06160, loss = 0.23  (301.5 images/sec)
# 00:07:49: epoch 21 / 30, iter 06180, loss = 0.23  (301.8 images/sec)
# 00:07:49: epoch 21 / 30, iter 06200, loss = 0.24  (299.0 images/sec)
# 00:07:50: epoch 21 / 30, iter 06220, loss = 0.27  (300.5 images/sec)
# 00:07:51: epoch 21 / 30, iter 06240, loss = 0.21  (303.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (715.6 images/sec)
# batch 010 loss = 0.32  (706.5 images/sec)
# batch 020 loss = 0.40  (674.2 images/sec)
# batch 030 loss = 0.25  (668.1 images/sec)
# batch 040 loss = 0.27  (679.4 images/sec)
# [[11496483    43291    27762    39493       95    44618   108880]
#  [   92377  6179749    59076   308171    54470    55940   117073]
#  [   85421   434675   138391   219120    13696    34068    60574]
#  [   83638   331775    35799  4904903    37495    13553    59694]
#  [       0    42894     2338    35378   826099        3      159]
#  [   36299    85478     8921    27317       68   258879    62026]
#  [  102985   143388    15068    60550      841    49913  2183296]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.53 %
# 	building IoU accuracy = 77.75 %
# 	infrastructure IoU accuracy = 12.19 %
# 	nature IoU accuracy = 79.67 %
# 	sky IoU accuracy = 81.51 %
# 	person IoU accuracy = 38.23 %
# 	vehicle IoU accuracy = 73.65 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.36 %
# Validation pixel accuracy = 89.54 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 65.36 (epoch 21)
#
# Training phase:
# 00:08:04: epoch 22 / 30, iter 06260, loss = 0.25  (277.1 images/sec)
# 00:08:05: epoch 22 / 30, iter 06280, loss = 0.22  (300.2 images/sec)
# 00:08:06: epoch 22 / 30, iter 06300, loss = 0.25  (299.2 images/sec)
# 00:08:06: epoch 22 / 30, iter 06320, loss = 0.23  (299.6 images/sec)
# 00:08:07: epoch 22 / 30, iter 06340, loss = 0.24  (301.9 images/sec)
# 00:08:08: epoch 22 / 30, iter 06360, loss = 0.23  (318.6 images/sec)
# 00:08:08: epoch 22 / 30, iter 06380, loss = 0.24  (298.8 images/sec)
# 00:08:09: epoch 22 / 30, iter 06400, loss = 0.30  (293.9 images/sec)
# 00:08:10: epoch 22 / 30, iter 06420, loss = 0.21  (316.6 images/sec)
# 00:08:10: epoch 22 / 30, iter 06440, loss = 0.22  (297.7 images/sec)
# 00:08:11: epoch 22 / 30, iter 06460, loss = 0.29  (302.4 images/sec)
# 00:08:12: epoch 22 / 30, iter 06480, loss = 0.23  (303.0 images/sec)
# 00:08:12: epoch 22 / 30, iter 06500, loss = 0.25  (301.2 images/sec)
# 00:08:13: epoch 22 / 30, iter 06520, loss = 0.19  (300.5 images/sec)
# 00:08:14: epoch 22 / 30, iter 06540, loss = 0.30  (297.3 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (711.2 images/sec)
# batch 010 loss = 0.33  (722.7 images/sec)
# batch 020 loss = 0.40  (706.3 images/sec)
# batch 030 loss = 0.25  (704.9 images/sec)
# batch 040 loss = 0.26  (713.5 images/sec)
# [[11522367    51877    23352    35176      142    31906    95802]
#  [   93468  6198416    55161   278189    52978    46791   141853]
#  [   89795   461463   129147   201724    13606    29178    61032]
#  [   91141   363059    48012  4853760    36248    12913    61724]
#  [       0    39357     2924    39092   825253        0      245]
#  [   44394    95943    10579    23525       84   232440    72023]
#  [  117432   136433    16100    52038      740    37839  2195459]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.47 %
# 	building IoU accuracy = 77.34 %
# 	infrastructure IoU accuracy = 11.31 %
# 	nature IoU accuracy = 79.61 %
# 	sky IoU accuracy = 81.65 %
# 	person IoU accuracy = 36.45 %
# 	vehicle IoU accuracy = 73.46 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 64.90 %
# Validation pixel accuracy = 89.44 %
#
# Best IoU = 65.36 (epoch 21)
#
# Training phase:
# 00:08:27: epoch 23 / 30, iter 06560, loss = 0.26  (297.0 images/sec)
# 00:08:28: epoch 23 / 30, iter 06580, loss = 0.23  (300.9 images/sec)
# 00:08:28: epoch 23 / 30, iter 06600, loss = 0.24  (302.9 images/sec)
# 00:08:29: epoch 23 / 30, iter 06620, loss = 0.23  (301.4 images/sec)
# 00:08:30: epoch 23 / 30, iter 06640, loss = 0.27  (300.0 images/sec)
# ...
# batch 040 loss = 0.26  (680.5 images/sec)
# [[11534849    46472    27567    28102      131    31182    92319]
#  [   93345  6213384    66598   254570    53436    49736   135787]
#  [   92033   444043   154620   194712    12746    30098    57693]
#  [   98711   378377    55774  4821419    36054    15518    61004]
#  [       0    42411     3501    37001   823618        0      340]
#  [   47115    91474    12062    21776       63   248132    58366]
#  [  118173   131371    21722    49384      700    47692  2186999]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.47 %
# 	building IoU accuracy = 77.66 %
# 	infrastructure IoU accuracy = 13.18 %
# 	nature IoU accuracy = 79.66 %
# 	sky IoU accuracy = 81.55 %
# 	person IoU accuracy = 37.99 %
# 	vehicle IoU accuracy = 73.85 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.48 %
# Validation pixel accuracy = 89.53 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 65.48 (epoch 23)
#
# Training phase:
# 00:08:50: epoch 24 / 30, iter 06860, loss = 0.23  (288.0 images/sec)
# 00:08:51: epoch 24 / 30, iter 06880, loss = 0.23  (301.2 images/sec)
# 00:08:52: epoch 24 / 30, iter 06900, loss = 0.21  (302.0 images/sec)
# 00:08:52: epoch 24 / 30, iter 06920, loss = 0.22  (301.5 images/sec)
# 00:08:53: epoch 24 / 30, iter 06940, loss = 0.26  (299.4 images/sec)
# 00:08:54: epoch 24 / 30, iter 06960, loss = 0.18  (301.5 images/sec)
# 00:08:54: epoch 24 / 30, iter 06980, loss = 0.23  (301.9 images/sec)
# 00:08:55: epoch 24 / 30, iter 07000, loss = 0.24  (294.1 images/sec)
# 00:08:56: epoch 24 / 30, iter 07020, loss = 0.24  (298.8 images/sec)
# 00:08:56: epoch 24 / 30, iter 07040, loss = 0.22  (300.4 images/sec)
# 00:08:57: epoch 24 / 30, iter 07060, loss = 0.23  (302.1 images/sec)
# 00:08:58: epoch 24 / 30, iter 07080, loss = 0.32  (300.1 images/sec)
# 00:08:58: epoch 24 / 30, iter 07100, loss = 0.26  (299.8 images/sec)
# 00:08:59: epoch 24 / 30, iter 07120, loss = 0.22  (302.0 images/sec)
# 00:09:00: epoch 24 / 30, iter 07140, loss = 0.30  (296.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.33  (697.3 images/sec)
# batch 010 loss = 0.32  (716.7 images/sec)
# batch 020 loss = 0.38  (710.1 images/sec)
# batch 030 loss = 0.24  (712.2 images/sec)
# batch 040 loss = 0.26  (718.7 images/sec)
# [[11491979    34292    27880    40691      122    44539   121119]
#  [  103870  5961477   100853   372782    55316    76104   196454]
#  [   86367   370207   178941   220671    12984    42354    74421]
#  [   84670   250713    45367  4972138    29849    19200    64920]
#  [       0    34488     3947    45926   822005        3      502]
#  [   36807    65250     8346    24113       82   276815    67575]
#  [   92069    95718    13558    59507      775    50718  2243696]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.47 %
# 	building IoU accuracy = 77.25 %
# 	infrastructure IoU accuracy = 15.09 %
# 	nature IoU accuracy = 79.80 %
# 	sky IoU accuracy = 81.71 %
# 	person IoU accuracy = 38.88 %
# 	vehicle IoU accuracy = 72.82 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.72 %
# Validation pixel accuracy = 89.40 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 65.72 (epoch 24)
#
# Training phase:
# 00:09:14: epoch 25 / 30, iter 07160, loss = 0.23  (300.8 images/sec)
# 00:09:14: epoch 25 / 30, iter 07180, loss = 0.25  (285.9 images/sec)
# 00:09:15: epoch 25 / 30, iter 07200, loss = 0.24  (299.4 images/sec)
# 00:09:16: epoch 25 / 30, iter 07220, loss = 0.21  (299.2 images/sec)
# 00:09:16: epoch 25 / 30, iter 07240, loss = 0.22  (291.6 images/sec)
# 00:09:17: epoch 25 / 30, iter 07260, loss = 0.21  (300.1 images/sec)
# 00:09:18: epoch 25 / 30, iter 07280, loss = 0.24  (298.0 images/sec)
# 00:09:18: epoch 25 / 30, iter 07300, loss = 0.18  (300.3 images/sec)
# 00:09:19: epoch 25 / 30, iter 07320, loss = 0.25  (301.4 images/sec)
# 00:09:20: epoch 25 / 30, iter 07340, loss = 0.24  (302.4 images/sec)
# 00:09:20: epoch 25 / 30, iter 07360, loss = 0.23  (299.9 images/sec)
# 00:09:21: epoch 25 / 30, iter 07380, loss = 0.22  (304.6 images/sec)
# 00:09:22: epoch 25 / 30, iter 07400, loss = 0.20  (300.8 images/sec)
# 00:09:22: epoch 25 / 30, iter 07420, loss = 0.31  (299.1 images/sec)
# 00:09:23: epoch 25 / 30, iter 07440, loss = 0.20  (300.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.33  (672.8 images/sec)
# batch 010 loss = 0.33  (705.2 images/sec)
# batch 020 loss = 0.39  (684.1 images/sec)
# batch 030 loss = 0.24  (681.4 images/sec)
# batch 040 loss = 0.26  (681.7 images/sec)
# [[11524443    42300    24627    32383      149    36656   100064]
#  [   99941  6143022    75580   289682    63606    61954   133071]
#  [   92467   422131   164955   198073    13445    35609    59265]
#  [   92441   337576    54081  4868185    36828    17907    59839]
#  [       0    35833     3181    37554   830088        0      215]
#  [   44554    82246     9843    21852       67   266495    53931]
#  [  110238   131242    18145    51120     2048    58221  2185027]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.46 %
# 	building IoU accuracy = 77.58 %
# 	infrastructure IoU accuracy = 14.08 %
# 	nature IoU accuracy = 79.84 %
# 	sky IoU accuracy = 81.14 %
# 	person IoU accuracy = 38.66 %
# 	vehicle IoU accuracy = 73.76 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.65 %
# Validation pixel accuracy = 89.53 %
#
# Best IoU = 65.72 (epoch 24)
#
# Training phase:
# 00:09:36: epoch 26 / 30, iter 07460, loss = 0.25  (298.1 images/sec)
# 00:09:37: epoch 26 / 30, iter 07480, loss = 0.26  (300.2 images/sec)
# 00:09:38: epoch 26 / 30, iter 07500, loss = 0.24  (300.6 images/sec)
# 00:09:38: epoch 26 / 30, iter 07520, loss = 0.22  (300.8 images/sec)
# 00:09:39: epoch 26 / 30, iter 07540, loss = 0.20  (301.3 images/sec)
# 00:09:40: epoch 26 / 30, iter 07560, loss = 0.23  (301.1 images/sec)
# 00:09:40: epoch 26 / 30, iter 07580, loss = 0.22  (302.1 images/sec)
# 00:09:41: epoch 26 / 30, iter 07600, loss = 0.20  (302.0 images/sec)
# 00:09:42: epoch 26 / 30, iter 07620, loss = 0.22  (300.3 images/sec)
# 00:09:42: epoch 26 / 30, iter 07640, loss = 0.27  (301.9 images/sec)
# 00:09:43: epoch 26 / 30, iter 07660, loss = 0.22  (299.7 images/sec)
# 00:09:44: epoch 26 / 30, iter 07680, loss = 0.22  (302.6 images/sec)
# 00:09:44: epoch 26 / 30, iter 07700, loss = 0.20  (299.5 images/sec)
# 00:09:45: epoch 26 / 30, iter 07720, loss = 0.25  (297.4 images/sec)
# 00:09:46: epoch 26 / 30, iter 07740, loss = 0.24  (302.8 images/sec)
#
# Validation phase:
# batch 000 loss = 0.33  (697.8 images/sec)
# batch 010 loss = 0.31  (712.9 images/sec)
# batch 020 loss = 0.38  (719.5 images/sec)
# batch 030 loss = 0.24  (693.1 images/sec)
# batch 040 loss = 0.26  (705.1 images/sec)
# [[11487076    44434    28529    58731      124    34909   106819]
#  [   86880  6129540    80909   340734    55692    48439   124662]
#  [   84695   410202   168169   222868    12760    28006    59245]
#  [   66350   292499    38552  4972597    34270    13333    49256]
#  [       0    36423     4013    39753   826427        0      255]
#  [   42593    91691    10752    27838       75   246928    59111]
#  [  102959   132265    17019    68961      724    45403  2188710]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.59 %
# 	building IoU accuracy = 77.84 %
# 	infrastructure IoU accuracy = 14.43 %
# 	nature IoU accuracy = 79.87 %
# 	sky IoU accuracy = 81.78 %
# 	person IoU accuracy = 38.04 %
# 	vehicle IoU accuracy = 74.06 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.80 %
# Validation pixel accuracy = 89.65 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 65.80 (epoch 26)
#
# Training phase:
# 00:10:00: epoch 27 / 30, iter 07760, loss = 0.28  (303.0 images/sec)
# 00:10:00: epoch 27 / 30, iter 07780, loss = 0.23  (300.8 images/sec)
# 00:10:01: epoch 27 / 30, iter 07800, loss = 0.23  (297.9 images/sec)
# 00:10:02: epoch 27 / 30, iter 07820, loss = 0.21  (299.9 images/sec)
# 00:10:02: epoch 27 / 30, iter 07840, loss = 0.24  (301.0 images/sec)
# 00:10:03: epoch 27 / 30, iter 07860, loss = 0.26  (298.7 images/sec)
# 00:10:04: epoch 27 / 30, iter 07880, loss = 0.24  (301.5 images/sec)
# 00:10:04: epoch 27 / 30, iter 07900, loss = 0.23  (299.1 images/sec)
# 00:10:05: epoch 27 / 30, iter 07920, loss = 0.23  (322.0 images/sec)
# 00:10:06: epoch 27 / 30, iter 07940, loss = 0.24  (301.3 images/sec)
# 00:10:06: epoch 27 / 30, iter 07960, loss = 0.25  (299.9 images/sec)
# 00:10:07: epoch 27 / 30, iter 07980, loss = 0.18  (300.6 images/sec)
# 00:10:08: epoch 27 / 30, iter 08000, loss = 0.22  (301.2 images/sec)
# 00:10:08: epoch 27 / 30, iter 08020, loss = 0.21  (296.9 images/sec)
# 00:10:09: epoch 27 / 30, iter 08040, loss = 0.20  (295.7 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (697.4 images/sec)
# batch 010 loss = 0.32  (720.4 images/sec)
# batch 020 loss = 0.39  (685.6 images/sec)
# batch 030 loss = 0.24  (683.6 images/sec)
# batch 040 loss = 0.26  (674.1 images/sec)
# [[11504537    47334    36475    29096      123    36608   106449]
#  [   88447  6175055    89810   269634    54135    54639   135136]
#  [   83123   417735   188000   191857    13016    30255    61959]
#  [   96053   353120    64373  4834001    36149    16581    66580]
#  [       0    39299     3343    36665   827296        0      268]
#  [   41570    86004    14465    20451       71   258240    58187]
#  [  103932   128815    22908    45516      720    50710  2203440]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.50 %
# 	building IoU accuracy = 77.78 %
# 	infrastructure IoU accuracy = 15.44 %
# 	nature IoU accuracy = 79.77 %
# 	sky IoU accuracy = 81.82 %
# 	person IoU accuracy = 38.67 %
# 	vehicle IoU accuracy = 73.83 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.97 %
# Validation pixel accuracy = 89.55 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 65.97 (epoch 27)
#
# Training phase:
# 00:10:23: epoch 28 / 30, iter 08060, loss = 0.22  (295.6 images/sec)
# 00:10:23: epoch 28 / 30, iter 08080, loss = 0.21  (298.4 images/sec)
# 00:10:24: epoch 28 / 30, iter 08100, loss = 0.24  (300.3 images/sec)
# 00:10:25: epoch 28 / 30, iter 08120, loss = 0.21  (300.6 images/sec)
# 00:10:25: epoch 28 / 30, iter 08140, loss = 0.21  (303.0 images/sec)
# 00:10:26: epoch 28 / 30, iter 08160, loss = 0.25  (303.4 images/sec)
# 00:10:27: epoch 28 / 30, iter 08180, loss = 0.22  (298.7 images/sec)
# 00:10:27: epoch 28 / 30, iter 08200, loss = 0.21  (301.7 images/sec)
# 00:10:28: epoch 28 / 30, iter 08220, loss = 0.22  (296.8 images/sec)
# 00:10:29: epoch 28 / 30, iter 08240, loss = 0.23  (302.8 images/sec)
# 00:10:29: epoch 28 / 30, iter 08260, loss = 0.27  (301.8 images/sec)
# 00:10:30: epoch 28 / 30, iter 08280, loss = 0.22  (302.7 images/sec)
# 00:10:31: epoch 28 / 30, iter 08300, loss = 0.25  (299.0 images/sec)
# 00:10:31: epoch 28 / 30, iter 08320, loss = 0.23  (300.9 images/sec)
# 00:10:32: epoch 28 / 30, iter 08340, loss = 0.21  (297.1 images/sec)
#
# Validation phase:
# batch 000 loss = 0.33  (718.4 images/sec)
# batch 010 loss = 0.32  (718.0 images/sec)
# batch 020 loss = 0.39  (727.4 images/sec)
# batch 030 loss = 0.24  (708.2 images/sec)
# batch 040 loss = 0.27  (720.9 images/sec)
# [[11491940    43819    32509    40061      124    39820   112349]
#  [   90138  6168037    76218   281158    48171    56876   146258]
#  [   84983   419575   170358   199880    12885    33113    65151]
#  [   80440   341695    50550  4877968    34403    16962    64839]
#  [       0    43005     2882    38212   822460        0      312]
#  [   40987    86462     9817    21687       72   263152    56811]
#  [   98813   126422    16784    50640      867    52060  2210455]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.54 %
# 	building IoU accuracy = 77.80 %
# 	infrastructure IoU accuracy = 14.50 %
# 	nature IoU accuracy = 79.99 %
# 	sky IoU accuracy = 81.97 %
# 	person IoU accuracy = 38.82 %
# 	vehicle IoU accuracy = 73.64 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.89 %
# Validation pixel accuracy = 89.60 %
#
# Best IoU = 65.97 (epoch 27)
#
# Training phase:
# 00:10:45: epoch 29 / 30, iter 08360, loss = 0.19  (301.0 images/sec)
# 00:10:46: epoch 29 / 30, iter 08380, loss = 0.26  (302.7 images/sec)
# 00:10:47: epoch 29 / 30, iter 08400, loss = 0.20  (319.5 images/sec)
# 00:10:47: epoch 29 / 30, iter 08420, loss = 0.25  (302.0 images/sec)
# 00:10:48: epoch 29 / 30, iter 08440, loss = 0.24  (300.5 images/sec)
# 00:10:49: epoch 29 / 30, iter 08460, loss = 0.20  (299.4 images/sec)
# 00:10:49: epoch 29 / 30, iter 08480, loss = 0.21  (301.6 images/sec)
# 00:10:50: epoch 29 / 30, iter 08500, loss = 0.19  (300.1 images/sec)
# 00:10:51: epoch 29 / 30, iter 08520, loss = 0.21  (304.3 images/sec)
# 00:10:51: epoch 29 / 30, iter 08540, loss = 0.19  (299.4 images/sec)
# 00:10:52: epoch 29 / 30, iter 08560, loss = 0.21  (302.4 images/sec)
# 00:10:53: epoch 29 / 30, iter 08580, loss = 0.18  (300.6 images/sec)
# 00:10:53: epoch 29 / 30, iter 08600, loss = 0.26  (301.3 images/sec)
# 00:10:54: epoch 29 / 30, iter 08620, loss = 0.26  (300.1 images/sec)
# 00:10:55: epoch 29 / 30, iter 08640, loss = 0.21  (300.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.33  (717.6 images/sec)
# batch 010 loss = 0.32  (708.1 images/sec)
# batch 020 loss = 0.38  (687.8 images/sec)
# batch 030 loss = 0.24  (685.8 images/sec)
# batch 040 loss = 0.26  (681.8 images/sec)
# [[11493174    55721    27049    37452      120    37541   109565]
#  [   81704  6194985    74403   289398    48316    51384   126666]
#  [   83332   430844   164820   203079    12655    30670    60545]
#  [   83506   336361    51732  4887095    33708    14969    59486]
#  [       0    42258     3575    39224   821558        0      256]
#  [   40539    91672     9256    23565       75   254662    59219]
#  [   99230   137967    16303    53463      706    47139  2201233]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.60 %
# 	building IoU accuracy = 77.81 %
# 	infrastructure IoU accuracy = 14.11 %
# 	nature IoU accuracy = 79.95 %
# 	sky IoU accuracy = 81.95 %
# 	person IoU accuracy = 38.54 %
# 	vehicle IoU accuracy = 74.07 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.86 %
# Validation pixel accuracy = 89.65 %
#
# Best IoU = 65.97 (epoch 27)
#
# Training phase:
# 00:11:08: epoch 30 / 30, iter 08660, loss = 0.21  (300.2 images/sec)
# 00:11:09: epoch 30 / 30, iter 08680, loss = 0.21  (298.8 images/sec)
# 00:11:10: epoch 30 / 30, iter 08700, loss = 0.24  (304.8 images/sec)
# 00:11:10: epoch 30 / 30, iter 08720, loss = 0.19  (300.1 images/sec)
# 00:11:11: epoch 30 / 30, iter 08740, loss = 0.21  (301.2 images/sec)
# 00:11:12: epoch 30 / 30, iter 08760, loss = 0.22  (296.5 images/sec)
# 00:11:12: epoch 30 / 30, iter 08780, loss = 0.21  (303.9 images/sec)
# 00:11:13: epoch 30 / 30, iter 08800, loss = 0.19  (301.1 images/sec)
# 00:11:14: epoch 30 / 30, iter 08820, loss = 0.25  (303.0 images/sec)
# 00:11:14: epoch 30 / 30, iter 08840, loss = 0.23  (302.0 images/sec)
# 00:11:15: epoch 30 / 30, iter 08860, loss = 0.23  (302.6 images/sec)
# 00:11:16: epoch 30 / 30, iter 08880, loss = 0.35  (317.2 images/sec)
# 00:11:16: epoch 30 / 30, iter 08900, loss = 0.24  (301.8 images/sec)
# 00:11:17: epoch 30 / 30, iter 08920, loss = 0.23  (298.6 images/sec)
#
# Validation phase:
# batch 000 loss = 0.33  (702.7 images/sec)
# batch 010 loss = 0.32  (718.8 images/sec)
# batch 020 loss = 0.39  (712.8 images/sec)
# batch 030 loss = 0.24  (722.9 images/sec)
# batch 040 loss = 0.26  (713.1 images/sec)
# [[11490361    48276    32824    39771      131    39269   109990]
#  [   84931  6144263    86356   312033    51630    55713   131930]
#  [   82169   411167   180475   208681    12875    32077    58501]
#  [   80607   307245    53075  4918982    34253    15614    57081]
#  [       0    39900     3463    39217   824041        0      250]
#  [   39805    85263    11503    24484       76   262299    55558]
#  [   97240   129648    19698    56965      888    50981  2200621]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.61 %
# 	building IoU accuracy = 77.89 %
# 	infrastructure IoU accuracy = 15.13 %
# 	nature IoU accuracy = 80.01 %
# 	sky IoU accuracy = 81.85 %
# 	person IoU accuracy = 39.00 %
# 	vehicle IoU accuracy = 74.11 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 66.09 %
# Validation pixel accuracy = 89.66 %
# Model saved in file:  local/checkpoint1/model.ckpt
#
# Best IoU = 66.09 (epoch 30)

# %% [markdown]
# ## 4. Restoring the pretrained network

# %%
# restore the best checkpoint
checkpoint_path = 'local/pretrained1/model.ckpt'
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path)
validate(sess, val_data, x, y, y_pred, loss, draw_steps=10)
# Out:
# INFO:tensorflow:Restoring parameters from local/pretrained1/model.ckpt
#
# Validation phase:
# batch 000 loss = 0.33  (693.5 images/sec)
# batch 010 loss = 0.32  (691.7 images/sec)
# batch 020 loss = 0.39  (704.2 images/sec)
# batch 030 loss = 0.24  (695.0 images/sec)
# batch 040 loss = 0.26  (695.1 images/sec)
# [[11490361    48276    32824    39771      131    39269   109990]
#  [   84931  6144263    86356   312033    51630    55713   131930]
#  [   82169   411167   180475   208681    12875    32077    58501]
#  [   80607   307245    53075  4918982    34253    15614    57081]
#  [       0    39900     3463    39217   824041        0      250]
#  [   39805    85263    11503    24484       76   262299    55558]
#  [   97240   129648    19698    56965      888    50981  2200621]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.61 %
# 	building IoU accuracy = 77.89 %
# 	infrastructure IoU accuracy = 15.13 %
# 	nature IoU accuracy = 80.01 %
# 	sky IoU accuracy = 81.85 %
# 	person IoU accuracy = 39.00 %
# 	vehicle IoU accuracy = 74.11 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 66.09 %
# Validation pixel accuracy = 89.66 %
# 66.085190395231365

# %% [markdown]
# ## Day 4

# %% [markdown]
# ## 5. Improved model with skip connections
#
# In this part we are going to improve on the pravious model by adding skip connections.

# %%
def upsample(x, skip, num_maps):
    skip_size = skip.get_shape().as_list()[1:3]
    x = tf.image.resize_bilinear(x, skip_size)
    x = tf.concat([x, skip], 3)
    return conv(x, num_maps)

# this functions takes the input placeholder and the number of classes, builds the model and returns the logits
def build_model(x, num_classes):
    input_size = x.get_shape().as_list()[1:3]
    block_sizes = [64, 64, 64, 64]
    skip_layers = []
    
    x = conv(x, 32, k=3)
    for i, size in enumerate(block_sizes):
        with tf.name_scope('block'+str(i)):
            x = pool(x)
            x = conv(x, size)
            x = conv(x, size)
            skip_layers.append(x)
    
    for i, skip in reversed(list(enumerate(skip_layers))):
        with tf.name_scope('block'+str(i)):
            print(i, x, '\n', skip)
            x = upsample(x, skip, block_sizes[i])
    
    with tf.name_scope('logits'):
        x = tf.layers.conv2d(x, num_classes, 1, padding='same')
        x = tf.image.resize_bilinear(x, input_size, name='upsample_logits')
    return x

# %%
sess.close()
tf.reset_default_graph()

# create inputs
x, y = build_inputs()
# create model
logits = build_model(x, num_classes)
# create loss
loss = build_loss(logits, y)
# we are going to need argmax predictions for IoU
y_pred = tf.argmax(logits, axis=3, output_type=tf.int32)
# Out:
# 3 Tensor("block3/Relu_1:0", shape=(?, 10, 24, 64), dtype=float32)
#  Tensor("block3/Relu_1:0", shape=(?, 10, 24, 64), dtype=float32)
# 2 Tensor("block3_1/Relu:0", shape=(?, 10, 24, 64), dtype=float32)
#  Tensor("block2/Relu_1:0", shape=(?, 20, 48, 64), dtype=float32)
# 1 Tensor("block2_1/Relu:0", shape=(?, 20, 48, 64), dtype=float32)
#  Tensor("block1/Relu_1:0", shape=(?, 40, 96, 64), dtype=float32)
# 0 Tensor("block1_1/Relu:0", shape=(?, 40, 96, 64), dtype=float32)
#  Tensor("block0/Relu_1:0", shape=(?, 80, 192, 64), dtype=float32)

# %%
sess = tf.Session()
train(sess, x, y, y_pred, loss, 'local/checkpoint2')
# Out:
# /usr/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:95: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Training phase:
# 00:00:00: epoch 1 / 30, iter 00000, loss = 1.95  (46.3 images/sec)
# 00:00:01: epoch 1 / 30, iter 00020, loss = 0.83  (169.1 images/sec)
# 00:00:03: epoch 1 / 30, iter 00040, loss = 0.83  (168.6 images/sec)
# 00:00:04: epoch 1 / 30, iter 00060, loss = 0.71  (169.1 images/sec)
# 00:00:05: epoch 1 / 30, iter 00080, loss = 0.59  (167.8 images/sec)
# 00:00:06: epoch 1 / 30, iter 00100, loss = 0.62  (169.1 images/sec)
# 00:00:07: epoch 1 / 30, iter 00120, loss = 0.65  (169.0 images/sec)
# 00:00:09: epoch 1 / 30, iter 00140, loss = 0.61  (168.4 images/sec)
# 00:00:10: epoch 1 / 30, iter 00160, loss = 0.47  (168.7 images/sec)
# 00:00:11: epoch 1 / 30, iter 00180, loss = 0.49  (174.0 images/sec)
# 00:00:12: epoch 1 / 30, iter 00200, loss = 0.53  (168.4 images/sec)
# 00:00:13: epoch 1 / 30, iter 00220, loss = 0.44  (168.4 images/sec)
# 00:00:14: epoch 1 / 30, iter 00240, loss = 0.49  (168.9 images/sec)
# 00:00:16: epoch 1 / 30, iter 00260, loss = 0.48  (168.0 images/sec)
# 00:00:17: epoch 1 / 30, iter 00280, loss = 0.40  (167.9 images/sec)
#
# Validation phase:
# batch 000 loss = 0.47  (381.8 images/sec)
# batch 010 loss = 0.48  (553.9 images/sec)
# batch 020 loss = 0.58  (524.9 images/sec)
# batch 030 loss = 0.37  (516.2 images/sec)
# batch 040 loss = 0.38  (515.7 images/sec)
# [[11348872    40828       26    11286      254    11733   347623]
#  [  161823  5716776       24   276191   232268    60595   419179]
#  [   90571   562847       90   131893     8800    44691   147053]
#  [  146620   721952       29  4365008    44580     7747   180921]
#  [      89    27590        0     9490   868800        3      899]
#  [   29247   171337        9     8836      211    77238   192110]
#  [  133740   311472       27    43453    15524    39190  2012635]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 92.10 %
# 	building IoU accuracy = 65.69 %
# 	infrastructure IoU accuracy = 0.01 %
# 	nature IoU accuracy = 73.39 %
# 	sky IoU accuracy = 71.89 %
# 	person IoU accuracy = 12.01 %
# 	vehicle IoU accuracy = 52.36 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 52.49 %
# Validation pixel accuracy = 84.04 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 52.49 (epoch 1)
#
# Training phase:
# 00:00:33: epoch 2 / 30, iter 00300, loss = 0.47  (147.4 images/sec)
# 00:00:34: epoch 2 / 30, iter 00320, loss = 0.50  (168.2 images/sec)
# 00:00:35: epoch 2 / 30, iter 00340, loss = 0.38  (167.2 images/sec)
# 00:00:36: epoch 2 / 30, iter 00360, loss = 0.51  (167.5 images/sec)
# 00:00:37: epoch 2 / 30, iter 00380, loss = 0.51  (167.0 images/sec)
# 00:00:39: epoch 2 / 30, iter 00400, loss = 0.41  (168.3 images/sec)
# 00:00:40: epoch 2 / 30, iter 00420, loss = 0.42  (167.6 images/sec)
# 00:00:41: epoch 2 / 30, iter 00440, loss = 0.42  (168.8 images/sec)
# 00:00:42: epoch 2 / 30, iter 00460, loss = 0.41  (166.7 images/sec)
# 00:00:43: epoch 2 / 30, iter 00480, loss = 0.37  (168.0 images/sec)
# 00:00:45: epoch 2 / 30, iter 00500, loss = 0.44  (167.9 images/sec)
# 00:00:46: epoch 2 / 30, iter 00520, loss = 0.32  (167.2 images/sec)
# 00:00:47: epoch 2 / 30, iter 00540, loss = 0.44  (173.4 images/sec)
# 00:00:48: epoch 2 / 30, iter 00560, loss = 0.36  (166.2 images/sec)
# 00:00:49: epoch 2 / 30, iter 00580, loss = 0.37  (167.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.42  (560.3 images/sec)
# batch 010 loss = 0.45  (556.3 images/sec)
# batch 020 loss = 0.53  (595.9 images/sec)
# batch 030 loss = 0.32  (555.7 images/sec)
# batch 040 loss = 0.33  (551.7 images/sec)
# [[11381209    61929     4065    18029      164     5229   289997]
#  [  138883  6174900     2033   167482    80989    30247   272322]
#  [   78433   635517    13861   125476     3223    20684   108751]
#  [  115996   845860     1462  4343126    16130     4098   140185]
#  [       2    83973      124    17031   805688        0       53]
#  [   26932   217615     5653    11539       26    71928   145295]
#  [   99234   430659     4220    47935     3903    29922  1940168]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 93.14 %
# 	building IoU accuracy = 67.54 %
# 	infrastructure IoU accuracy = 1.38 %
# 	nature IoU accuracy = 74.19 %
# 	sky IoU accuracy = 79.67 %
# 	person IoU accuracy = 12.64 %
# 	vehicle IoU accuracy = 55.23 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 54.83 %
# Validation pixel accuracy = 85.21 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 54.83 (epoch 2)
#
# Training phase:
# 00:01:05: epoch 3 / 30, iter 00600, loss = 0.42  (168.0 images/sec)
# 00:01:06: epoch 3 / 30, iter 00620, loss = 0.30  (166.9 images/sec)
# 00:01:07: epoch 3 / 30, iter 00640, loss = 0.46  (165.2 images/sec)
# 00:01:08: epoch 3 / 30, iter 00660, loss = 0.39  (167.0 images/sec)
# 00:01:09: epoch 3 / 30, iter 00680, loss = 0.42  (167.6 images/sec)
# 00:01:11: epoch 3 / 30, iter 00700, loss = 0.47  (167.3 images/sec)
# 00:01:12: epoch 3 / 30, iter 00720, loss = 0.36  (168.1 images/sec)
# 00:01:13: epoch 3 / 30, iter 00740, loss = 0.40  (166.6 images/sec)
# 00:01:14: epoch 3 / 30, iter 00760, loss = 0.39  (166.4 images/sec)
# 00:01:15: epoch 3 / 30, iter 00780, loss = 0.55  (167.0 images/sec)
# 00:01:17: epoch 3 / 30, iter 00800, loss = 0.42  (167.8 images/sec)
# 00:01:18: epoch 3 / 30, iter 00820, loss = 0.34  (166.9 images/sec)
# 00:01:19: epoch 3 / 30, iter 00840, loss = 0.36  (167.3 images/sec)
# 00:01:20: epoch 3 / 30, iter 00860, loss = 0.39  (165.6 images/sec)
# 00:01:21: epoch 3 / 30, iter 00880, loss = 0.28  (171.8 images/sec)
#
# Validation phase:
# batch 000 loss = 0.39  (550.8 images/sec)
# batch 010 loss = 0.41  (557.4 images/sec)
# batch 020 loss = 0.49  (521.3 images/sec)
# batch 030 loss = 0.26  (513.0 images/sec)
# batch 040 loss = 0.28  (513.2 images/sec)
# [[11496758   124239     4873    23901      178    20563    90110]
#  [  139228  6170413     4939   276592    65203    50941   159540]
#  [   65697   572441    30047   183043     5205    52532    76980]
#  [  106000   602513     2675  4675261    20053     5844    54511]
#  [       0    71847      534    20694   813495        5      296]
#  [   25871   153934     4254    19536       46   172211   103136]
#  [  114873   302200     3799    57284      511    47902  2029472]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.14 %
# 	building IoU accuracy = 70.97 %
# 	infrastructure IoU accuracy = 2.98 %
# 	nature IoU accuracy = 77.30 %
# 	sky IoU accuracy = 81.51 %
# 	person IoU accuracy = 26.22 %
# 	vehicle IoU accuracy = 66.75 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 59.98 %
# Validation pixel accuracy = 87.48 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 59.98 (epoch 3)
#
# Training phase:
# 00:01:37: epoch 4 / 30, iter 00900, loss = 0.44  (162.2 images/sec)
# 00:01:38: epoch 4 / 30, iter 00920, loss = 0.31  (166.7 images/sec)
# 00:01:39: epoch 4 / 30, iter 00940, loss = 0.32  (166.9 images/sec)
# 00:01:41: epoch 4 / 30, iter 00960, loss = 0.50  (166.4 images/sec)
# 00:01:42: epoch 4 / 30, iter 00980, loss = 0.38  (166.9 images/sec)
# 00:01:43: epoch 4 / 30, iter 01000, loss = 0.26  (167.1 images/sec)
# 00:01:44: epoch 4 / 30, iter 01020, loss = 0.36  (166.6 images/sec)
# 00:01:45: epoch 4 / 30, iter 01040, loss = 0.30  (167.1 images/sec)
# 00:01:47: epoch 4 / 30, iter 01060, loss = 0.41  (166.7 images/sec)
# 00:01:48: epoch 4 / 30, iter 01080, loss = 0.27  (167.4 images/sec)
# 00:01:49: epoch 4 / 30, iter 01100, loss = 0.30  (165.9 images/sec)
# 00:01:50: epoch 4 / 30, iter 01120, loss = 0.33  (166.6 images/sec)
# 00:01:51: epoch 4 / 30, iter 01140, loss = 0.41  (171.6 images/sec)
# 00:01:53: epoch 4 / 30, iter 01160, loss = 0.42  (164.2 images/sec)
# 00:01:54: epoch 4 / 30, iter 01180, loss = 0.30  (166.8 images/sec)
#
# Validation phase:
# batch 000 loss = 0.35  (555.5 images/sec)
# batch 010 loss = 0.35  (559.3 images/sec)
# batch 020 loss = 0.45  (542.0 images/sec)
# batch 030 loss = 0.26  (548.7 images/sec)
# batch 040 loss = 0.30  (547.9 images/sec)
# [[11531767    35771    10035    44664      170    40479    97736]
#  [  167831  5902564    52902   396232    66247    93704   187376]
#  [   67820   432728    90822   202549     4520    90663    96843]
#  [   92340   328741    18931  4933087    19308    12334    62116]
#  [       0    34278     1678    22780   847848       46      241]
#  [   20090    88113     6869    20881       21   243595    99419]
#  [  119204   170216     6646    65234      435    76429  2117877]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.31 %
# 	building IoU accuracy = 74.18 %
# 	infrastructure IoU accuracy = 8.39 %
# 	nature IoU accuracy = 79.32 %
# 	sky IoU accuracy = 84.99 %
# 	person IoU accuracy = 30.73 %
# 	vehicle IoU accuracy = 68.32 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 62.89 %
# Validation pixel accuracy = 88.44 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 62.89 (epoch 4)
#
# Training phase:
# 00:02:09: epoch 5 / 30, iter 01200, loss = 0.35  (166.4 images/sec)
# 00:02:10: epoch 5 / 30, iter 01220, loss = 0.25  (167.9 images/sec)
# 00:02:12: epoch 5 / 30, iter 01240, loss = 0.35  (166.8 images/sec)
# 00:02:13: epoch 5 / 30, iter 01260, loss = 0.31  (165.6 images/sec)
# 00:02:14: epoch 5 / 30, iter 01280, loss = 0.36  (166.9 images/sec)
# 00:02:15: epoch 5 / 30, iter 01300, loss = 0.37  (166.7 images/sec)
# 00:02:16: epoch 5 / 30, iter 01320, loss = 0.26  (167.1 images/sec)
# 00:02:18: epoch 5 / 30, iter 01340, loss = 0.34  (166.8 images/sec)
# 00:02:19: epoch 5 / 30, iter 01360, loss = 0.25  (166.3 images/sec)
# 00:02:20: epoch 5 / 30, iter 01380, loss = 0.28  (165.3 images/sec)
# 00:02:21: epoch 5 / 30, iter 01400, loss = 0.28  (163.7 images/sec)
# 00:02:22: epoch 5 / 30, iter 01420, loss = 0.44  (165.6 images/sec)
# 00:02:24: epoch 5 / 30, iter 01440, loss = 0.30  (165.9 images/sec)
# 00:02:25: epoch 5 / 30, iter 01460, loss = 0.27  (165.7 images/sec)
# 00:02:26: epoch 5 / 30, iter 01480, loss = 0.28  (166.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.35  (554.7 images/sec)
# batch 010 loss = 0.33  (555.9 images/sec)
# batch 020 loss = 0.44  (515.9 images/sec)
# batch 030 loss = 0.25  (519.6 images/sec)
# batch 040 loss = 0.37  (518.5 images/sec)
# [[11461098    33303    14030    54182      198    40955   156856]
#  [  130218  5625917    78618   634128    83106   130722   184147]
#  [   59498   374460   131136   230845     5834    90405    93767]
#  [   75627   191147    31892  5069517    21542    13807    63325]
#  [      28    26648     1899    19320   858696       15      265]
#  [   16168    61618     8159    24644       28   265646   102725]
#  [   50938   172856     8411    87788     1208    65247  2169593]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.77 %
# 	building IoU accuracy = 72.81 %
# 	infrastructure IoU accuracy = 11.62 %
# 	nature IoU accuracy = 77.78 %
# 	sky IoU accuracy = 84.29 %
# 	person IoU accuracy = 32.39 %
# 	vehicle IoU accuracy = 68.72 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 63.20 %
# Validation pixel accuracy = 88.15 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 63.20 (epoch 5)
#
# Training phase:
# 00:02:42: epoch 6 / 30, iter 01500, loss = 0.37  (167.7 images/sec)
# 00:02:43: epoch 6 / 30, iter 01520, loss = 0.33  (165.9 images/sec)
# 00:02:44: epoch 6 / 30, iter 01540, loss = 0.33  (166.2 images/sec)
# 00:02:45: epoch 6 / 30, iter 01560, loss = 0.28  (165.7 images/sec)
# 00:02:46: epoch 6 / 30, iter 01580, loss = 0.30  (167.5 images/sec)
# 00:02:48: epoch 6 / 30, iter 01600, loss = 0.35  (166.5 images/sec)
# 00:02:49: epoch 6 / 30, iter 01620, loss = 0.39  (166.4 images/sec)
# 00:02:50: epoch 6 / 30, iter 01640, loss = 0.22  (173.0 images/sec)
# 00:02:51: epoch 6 / 30, iter 01660, loss = 0.28  (167.5 images/sec)
# 00:02:52: epoch 6 / 30, iter 01680, loss = 0.30  (165.5 images/sec)
# 00:02:54: epoch 6 / 30, iter 01700, loss = 0.28  (167.0 images/sec)
# 00:02:55: epoch 6 / 30, iter 01720, loss = 0.31  (166.2 images/sec)
# 00:02:56: epoch 6 / 30, iter 01740, loss = 0.20  (172.1 images/sec)
# 00:02:57: epoch 6 / 30, iter 01760, loss = 0.30  (166.6 images/sec)
# 00:02:58: epoch 6 / 30, iter 01780, loss = 0.30  (166.2 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (541.6 images/sec)
# batch 010 loss = 0.35  (558.9 images/sec)
# batch 020 loss = 0.42  (554.5 images/sec)
# batch 030 loss = 0.25  (551.8 images/sec)
# batch 040 loss = 0.27  (552.3 images/sec)
# [[11495145    55281    10294    15797      211    20835   163059]
#  [  111022  6225037    33226   243232   107032    34204   113103]
#  [   65064   518274   105632   153279     7144    54074    82478]
#  [  105439   435294    22769  4807382    25869     6962    63142]
#  [       1    15280     1444    15702   874277        0      167]
#  [   22892   118664    11801    14442       79   210385   100725]
#  [   59970   279129     8399    41256      899    44920  2121468]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.81 %
# 	building IoU accuracy = 75.10 %
# 	infrastructure IoU accuracy = 9.84 %
# 	nature IoU accuracy = 80.79 %
# 	sky IoU accuracy = 83.42 %
# 	person IoU accuracy = 32.87 %
# 	vehicle IoU accuracy = 68.91 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 63.68 %
# Validation pixel accuracy = 89.03 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 63.68 (epoch 6)
#
# Training phase:
# 00:03:14: epoch 7 / 30, iter 01800, loss = 0.33  (170.5 images/sec)
# 00:03:15: epoch 7 / 30, iter 01820, loss = 0.34  (165.9 images/sec)
# 00:03:16: epoch 7 / 30, iter 01840, loss = 0.22  (166.0 images/sec)
# 00:03:18: epoch 7 / 30, iter 01860, loss = 0.24  (166.0 images/sec)
# 00:03:19: epoch 7 / 30, iter 01880, loss = 0.27  (166.3 images/sec)
# 00:03:20: epoch 7 / 30, iter 01900, loss = 0.22  (164.9 images/sec)
# 00:03:21: epoch 7 / 30, iter 01920, loss = 0.28  (165.9 images/sec)
# 00:03:22: epoch 7 / 30, iter 01940, loss = 0.28  (166.8 images/sec)
# 00:03:24: epoch 7 / 30, iter 01960, loss = 0.31  (164.7 images/sec)
# 00:03:25: epoch 7 / 30, iter 01980, loss = 0.23  (166.5 images/sec)
# 00:03:26: epoch 7 / 30, iter 02000, loss = 0.29  (165.0 images/sec)
# 00:03:27: epoch 7 / 30, iter 02020, loss = 0.35  (166.3 images/sec)
# 00:03:28: epoch 7 / 30, iter 02040, loss = 0.25  (163.6 images/sec)
# 00:03:30: epoch 7 / 30, iter 02060, loss = 0.24  (166.9 images/sec)
# 00:03:31: epoch 7 / 30, iter 02080, loss = 0.24  (165.6 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (552.3 images/sec)
# batch 010 loss = 0.32  (548.7 images/sec)
# batch 020 loss = 0.44  (519.4 images/sec)
# batch 030 loss = 0.21  (513.2 images/sec)
# batch 040 loss = 0.26  (515.7 images/sec)
# [[11458877    25274    14281    37807      198    20189   203996]
#  [  125732  5962567    54327   388025    93250    58499   184456]
#  [   67912   429184   143362   196972     5891    51451    91173]
#  [   72819   253462    23568  5031489    24173     8879    52467]
#  [       1    26013     1026    14079   865195       21      536]
#  [   25726    84984    11769    18665       24   254153    83667]
#  [   53687   135135    12541    54744      463    46026  2253445]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 94.65 %
# 	building IoU accuracy = 76.24 %
# 	infrastructure IoU accuracy = 12.99 %
# 	nature IoU accuracy = 81.45 %
# 	sky IoU accuracy = 83.93 %
# 	person IoU accuracy = 38.27 %
# 	vehicle IoU accuracy = 71.03 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 65.51 %
# Validation pixel accuracy = 89.48 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 65.51 (epoch 7)
#
# Training phase:
# 00:03:46: epoch 8 / 30, iter 02100, loss = 0.26  (166.0 images/sec)
# 00:03:48: epoch 8 / 30, iter 02120, loss = 0.36  (172.6 images/sec)
# 00:03:49: epoch 8 / 30, iter 02140, loss = 0.30  (166.5 images/sec)
# 00:03:50: epoch 8 / 30, iter 02160, loss = 0.22  (166.3 images/sec)
# 00:03:51: epoch 8 / 30, iter 02180, loss = 0.40  (166.5 images/sec)
# 00:03:52: epoch 8 / 30, iter 02200, loss = 0.37  (166.0 images/sec)
# 00:03:54: epoch 8 / 30, iter 02220, loss = 0.31  (166.6 images/sec)
# 00:03:55: epoch 8 / 30, iter 02240, loss = 0.23  (167.2 images/sec)
# 00:03:56: epoch 8 / 30, iter 02260, loss = 0.28  (166.6 images/sec)
# 00:03:57: epoch 8 / 30, iter 02280, loss = 0.20  (166.9 images/sec)
# 00:03:58: epoch 8 / 30, iter 02300, loss = 0.30  (169.0 images/sec)
# 00:04:00: epoch 8 / 30, iter 02320, loss = 0.24  (165.9 images/sec)
# 00:04:01: epoch 8 / 30, iter 02340, loss = 0.29  (166.5 images/sec)
# 00:04:02: epoch 8 / 30, iter 02360, loss = 0.22  (165.8 images/sec)
# 00:04:03: epoch 8 / 30, iter 02380, loss = 0.27  (165.9 images/sec)
#
# Validation phase:
# batch 000 loss = 0.34  (550.7 images/sec)
# batch 010 loss = 0.32  (543.6 images/sec)
# batch 020 loss = 0.40  (547.3 images/sec)
# batch 030 loss = 0.23  (546.4 images/sec)
# batch 040 loss = 0.32  (551.7 images/sec)
# [[11524405    87132    32013    58761      214     8867    49230]
#  [   76393  6113617    93874   454154    50900     6432    71486]
#  [   47148   456054   230316   208953     5609     7790    30075]
#  [   63410   240730    42317  5065127    31078     1085    23110]
#  [       1    28827     3275     9077   865275       11      405]
#  [   25611   159088    83046    39757       42   132316    39128]
#  [  100020   231029    63738   111902      497    29939  2018916]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 95.45 %
# 	building IoU accuracy = 75.76 %
# 	infrastructure IoU accuracy = 17.66 %
# 	nature IoU accuracy = 79.77 %
# 	sky IoU accuracy = 86.94 %
# 	person IoU accuracy = 24.82 %
# 	vehicle IoU accuracy = 72.90 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 64.76 %
# Validation pixel accuracy = 89.41 %
#
# Best IoU = 65.51 (epoch 7)
#
# Training phase:
# 00:04:18: epoch 9 / 30, iter 02400, loss = 0.26  (166.4 images/sec)
# 00:04:19: epoch 9 / 30, iter 02420, loss = 0.19  (167.0 images/sec)
# 00:04:20: epoch 9 / 30, iter 02440, loss = 0.32  (165.7 images/sec)
# 00:04:21: epoch 9 / 30, iter 02460, loss = 0.25  (166.3 images/sec)
# 00:04:22: epoch 9 / 30, iter 02480, loss = 0.22  (166.8 images/sec)
# 00:04:24: epoch 9 / 30, iter 02500, loss = 0.21  (167.2 images/sec)
# 00:04:25: epoch 9 / 30, iter 02520, loss = 0.24  (164.1 images/sec)
# 00:04:26: epoch 9 / 30, iter 02540, loss = 0.24  (165.5 images/sec)
# 00:04:27: epoch 9 / 30, iter 02560, loss = 0.22  (166.5 images/sec)
# 00:04:28: epoch 9 / 30, iter 02580, loss = 0.27  (166.8 images/sec)
# 00:04:30: epoch 9 / 30, iter 02600, loss = 0.22  (165.8 images/sec)
# 00:04:31: epoch 9 / 30, iter 02620, loss = 0.22  (166.5 images/sec)
# 00:04:32: epoch 9 / 30, iter 02640, loss = 0.21  (162.0 images/sec)
# 00:04:33: epoch 9 / 30, iter 02660, loss = 0.27  (166.3 images/sec)
# 00:04:34: epoch 9 / 30, iter 02680, loss = 0.25  (166.7 images/sec)
#
# Validation phase:
# batch 000 loss = 0.33  (557.4 images/sec)
# batch 010 loss = 0.32  (551.5 images/sec)
# batch 020 loss = 0.40  (512.0 images/sec)
# batch 030 loss = 0.23  (513.9 images/sec)
# batch 040 loss = 0.32  (515.7 images/sec)
# [[11554022    34778    21081    40314      169    33470    76788]
#  [  133129  5675195   148767   682017    32584    94575   100589]
#  [   57876   315568   232860   245095     4402    68153    61991]
#  [   79784   120030    35083  5177596    10966    12622    30776]
#  [      15    49106     2701    29298   825518       23      210]
#  [   17273    52458    21628    32579       17   298127    56906]
#  [   69683   148082    28940    84360      188    89320  2135468]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 95.34 %
# 	building IoU accuracy = 74.80 %
# 	infrastructure IoU accuracy = 18.72 %
# 	nature IoU accuracy = 78.68 %
# 	sky IoU accuracy = 86.42 %
# 	person IoU accuracy = 38.36 %
# 	vehicle IoU accuracy = 74.06 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 66.63 %
# Validation pixel accuracy = 89.24 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 66.63 (epoch 9)
#
# Training phase:
# 00:04:50: epoch 10 / 30, iter 02700, loss = 0.21  (167.1 images/sec)
# 00:04:51: epoch 10 / 30, iter 02720, loss = 0.26  (166.4 images/sec)
# 00:04:52: epoch 10 / 30, iter 02740, loss = 0.31  (166.2 images/sec)
# 00:04:54: epoch 10 / 30, iter 02760, loss = 0.28  (166.5 images/sec)
# 00:04:55: epoch 10 / 30, iter 02780, loss = 0.23  (166.4 images/sec)
# 00:04:56: epoch 10 / 30, iter 02800, loss = 0.21  (166.1 images/sec)
# 00:04:57: epoch 10 / 30, iter 02820, loss = 0.25  (167.3 images/sec)
# 00:04:58: epoch 10 / 30, iter 02840, loss = 0.20  (166.6 images/sec)
# 00:05:00: epoch 10 / 30, iter 02860, loss = 0.21  (172.2 images/sec)
# 00:05:01: epoch 10 / 30, iter 02880, loss = 0.22  (167.1 images/sec)
# 00:05:02: epoch 10 / 30, iter 02900, loss = 0.24  (165.7 images/sec)
# 00:05:03: epoch 10 / 30, iter 02920, loss = 0.24  (172.7 images/sec)
# 00:05:04: epoch 10 / 30, iter 02940, loss = 0.25  (167.0 images/sec)
# 00:05:06: epoch 10 / 30, iter 02960, loss = 0.24  (167.2 images/sec)
#
# Validation phase:
# batch 000 loss = 0.28  (553.4 images/sec)
# batch 010 loss = 0.29  (558.0 images/sec)
# batch 020 loss = 0.35  (549.9 images/sec)
# batch 030 loss = 0.20  (553.7 images/sec)
# batch 040 loss = 0.24  (555.0 images/sec)
# [[11550093    38233    28233    36512      190    22939    84422]
#  [  100604  6168280    99115   293350    50128    45467   109912]
#  [   53269   416729   251497   161174     5269    39205    58802]
#  [   66785   236023    64429  5031623    18847     9287    39863]
#  [       2    28378     1806    19102   856846       22      715]
#  [   20520    87571    24021    17420       33   281431    47992]
#  [   54659   153416    34363    57021      345    62366  2193871]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 95.80 %
# 	building IoU accuracy = 78.81 %
# 	infrastructure IoU accuracy = 20.32 %
# 	nature IoU accuracy = 83.15 %
# 	sky IoU accuracy = 87.28 %
# 	person IoU accuracy = 42.75 %
# 	vehicle IoU accuracy = 75.71 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 69.12 %
# Validation pixel accuracy = 90.74 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 69.12 (epoch 10)
#
# Training phase:
# 00:05:21: epoch 11 / 30, iter 02980, loss = 0.20  (164.9 images/sec)
# 00:05:22: epoch 11 / 30, iter 03000, loss = 0.19  (167.5 images/sec)
# 00:05:23: epoch 11 / 30, iter 03020, loss = 0.20  (166.8 images/sec)
# 00:05:25: epoch 11 / 30, iter 03040, loss = 0.23  (165.5 images/sec)
# 00:05:26: epoch 11 / 30, iter 03060, loss = 0.28  (165.4 images/sec)
# 00:05:27: epoch 11 / 30, iter 03080, loss = 0.21  (166.5 images/sec)
# 00:05:28: epoch 11 / 30, iter 03100, loss = 0.22  (166.0 images/sec)
# 00:05:29: epoch 11 / 30, iter 03120, loss = 0.24  (165.5 images/sec)
# 00:05:31: epoch 11 / 30, iter 03140, loss = 0.25  (166.2 images/sec)
# 00:05:32: epoch 11 / 30, iter 03160, loss = 0.24  (165.2 images/sec)
# 00:05:33: epoch 11 / 30, iter 03180, loss = 0.24  (166.4 images/sec)
# 00:05:34: epoch 11 / 30, iter 03200, loss = 0.30  (167.0 images/sec)
# 00:05:35: epoch 11 / 30, iter 03220, loss = 0.20  (167.1 images/sec)
# 00:05:37: epoch 11 / 30, iter 03240, loss = 0.24  (166.3 images/sec)
# 00:05:38: epoch 11 / 30, iter 03260, loss = 0.19  (165.4 images/sec)
#
# Validation phase:
# batch 000 loss = 0.28  (549.6 images/sec)
# batch 010 loss = 0.31  (552.6 images/sec)
# batch 020 loss = 0.35  (519.3 images/sec)
# batch 030 loss = 0.19  (512.6 images/sec)
# batch 040 loss = 0.22  (519.2 images/sec)
# [[11543982    57162    17541    24201      212    25305    92219]
#  [   88240  6235110    73176   245039    56038    38886   130367]
#  [   50174   434438   229368   151017     6384    40983    73581]
#  [   77954   274636    43232  4996993    23805     9660    40577]
#  [       0    24563     1605    14253   865760       38      652]
#  [   17238    90656    15703    16153       24   278386    60828]
#  [   45751   133934    15599    46584      385    50411  2263377]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 95.88 %
# 	building IoU accuracy = 79.10 %
# 	infrastructure IoU accuracy = 19.90 %
# 	nature IoU accuracy = 83.78 %
# 	sky IoU accuracy = 87.12 %
# 	person IoU accuracy = 43.21 %
# 	vehicle IoU accuracy = 76.61 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 69.37 %
# Validation pixel accuracy = 91.01 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 69.37 (epoch 11)
#
# Training phase:
# 00:05:53: epoch 12 / 30, iter 03280, loss = 0.29  (155.6 images/sec)
# 00:05:55: epoch 12 / 30, iter 03300, loss = 0.23  (165.8 images/sec)
# 00:05:56: epoch 12 / 30, iter 03320, loss = 0.28  (166.5 images/sec)
# 00:05:57: epoch 12 / 30, iter 03340, loss = 0.19  (167.0 images/sec)
# 00:05:58: epoch 12 / 30, iter 03360, loss = 0.16  (166.3 images/sec)
# 00:05:59: epoch 12 / 30, iter 03380, loss = 0.21  (165.6 images/sec)
# 00:06:01: epoch 12 / 30, iter 03400, loss = 0.22  (167.0 images/sec)
# 00:06:02: epoch 12 / 30, iter 03420, loss = 0.27  (166.9 images/sec)
# 00:06:03: epoch 12 / 30, iter 03440, loss = 0.26  (165.1 images/sec)
# 00:06:04: epoch 12 / 30, iter 03460, loss = 0.24  (166.5 images/sec)
# 00:06:05: epoch 12 / 30, iter 03480, loss = 0.26  (166.3 images/sec)
# 00:06:07: epoch 12 / 30, iter 03500, loss = 0.24  (172.3 images/sec)
# 00:06:08: epoch 12 / 30, iter 03520, loss = 0.20  (165.4 images/sec)
# 00:06:09: epoch 12 / 30, iter 03540, loss = 0.34  (166.2 images/sec)
# 00:06:10: epoch 12 / 30, iter 03560, loss = 0.27  (166.8 images/sec)
#
# Validation phase:
# batch 000 loss = 0.31  (550.6 images/sec)
# batch 010 loss = 0.31  (550.6 images/sec)
# batch 020 loss = 0.37  (553.5 images/sec)
# batch 030 loss = 0.19  (553.9 images/sec)
# batch 040 loss = 0.21  (550.9 images/sec)
# [[11529739    63650    29184    26810      198    36865    74176]
#  [   76907  6361257    71966   181385    34995    59204    81142]
#  [   44114   454511   248265   127527     5293    55341    50894]
#  [   72030   368020    61557  4881056    19179    25596    39419]
#  [       0    36180     1436    17148   851554       21      532]
#  [   14996    79615    16656     9030       20   327085    31586]
#  [   48385   166019    25805    33009      144   107321  2175358]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 95.94 %
# 	building IoU accuracy = 79.17 %
# 	infrastructure IoU accuracy = 20.82 %
# 	nature IoU accuracy = 83.27 %
# 	sky IoU accuracy = 88.09 %
# 	person IoU accuracy = 42.85 %
# 	vehicle IoU accuracy = 76.76 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 69.56 %
# Validation pixel accuracy = 90.88 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 69.56 (epoch 12)
#
# Training phase:
# 00:06:26: epoch 13 / 30, iter 03580, loss = 0.20  (165.6 images/sec)
# 00:06:27: epoch 13 / 30, iter 03600, loss = 0.26  (166.0 images/sec)
# 00:06:28: epoch 13 / 30, iter 03620, loss = 0.21  (165.7 images/sec)
# 00:06:29: epoch 13 / 30, iter 03640, loss = 0.21  (166.2 images/sec)
# 00:06:31: epoch 13 / 30, iter 03660, loss = 0.25  (167.2 images/sec)
# 00:06:32: epoch 13 / 30, iter 03680, loss = 0.18  (166.1 images/sec)
# 00:06:33: epoch 13 / 30, iter 03700, loss = 0.21  (166.0 images/sec)
# 00:06:34: epoch 13 / 30, iter 03720, loss = 0.16  (166.6 images/sec)
# 00:06:35: epoch 13 / 30, iter 03740, loss = 0.19  (166.1 images/sec)
# 00:06:37: epoch 13 / 30, iter 03760, loss = 0.18  (165.2 images/sec)
# 00:06:38: epoch 13 / 30, iter 03780, loss = 0.26  (165.4 images/sec)
# 00:06:39: epoch 13 / 30, iter 03800, loss = 0.24  (163.8 images/sec)
# 00:06:40: epoch 13 / 30, iter 03820, loss = 0.21  (166.7 images/sec)
# 00:06:41: epoch 13 / 30, iter 03840, loss = 0.20  (166.1 images/sec)
# 00:06:43: epoch 13 / 30, iter 03860, loss = 0.19  (165.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (553.5 images/sec)
# batch 010 loss = 0.29  (552.5 images/sec)
# batch 020 loss = 0.36  (519.6 images/sec)
# batch 030 loss = 0.18  (511.2 images/sec)
# batch 040 loss = 0.21  (513.0 images/sec)
# [[11505587    71165    14564    40638      211    21464   106993]
#  [   69337  6275108    50596   261489    69078    30779   110469]
#  [   46056   443019   215828   163772     6787    32711    77772]
#  [   56585   254337    27859  5062498    24135     6191    35252]
#  [       0    18532     1706    13056   873217       22      338]
#  [   16248    89350    12297    19020       36   273790    68247]
#  [   31338   132613    12217    49658     1005    42323  2286887]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.04 %
# 	building IoU accuracy = 79.68 %
# 	infrastructure IoU accuracy = 19.53 %
# 	nature IoU accuracy = 84.17 %
# 	sky IoU accuracy = 86.62 %
# 	person IoU accuracy = 44.70 %
# 	vehicle IoU accuracy = 77.39 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 69.73 %
# Validation pixel accuracy = 91.29 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 69.73 (epoch 13)
#
# Training phase:
# 00:06:58: epoch 14 / 30, iter 03880, loss = 0.21  (164.1 images/sec)
# 00:06:59: epoch 14 / 30, iter 03900, loss = 0.21  (165.8 images/sec)
# 00:07:00: epoch 14 / 30, iter 03920, loss = 0.21  (166.0 images/sec)
# 00:07:02: epoch 14 / 30, iter 03940, loss = 0.20  (166.5 images/sec)
# 00:07:03: epoch 14 / 30, iter 03960, loss = 0.21  (166.8 images/sec)
# 00:07:04: epoch 14 / 30, iter 03980, loss = 0.19  (166.6 images/sec)
# 00:07:05: epoch 14 / 30, iter 04000, loss = 0.22  (165.6 images/sec)
# 00:07:06: epoch 14 / 30, iter 04020, loss = 0.22  (165.4 images/sec)
# 00:07:08: epoch 14 / 30, iter 04040, loss = 0.24  (165.9 images/sec)
# 00:07:09: epoch 14 / 30, iter 04060, loss = 0.19  (164.1 images/sec)
# 00:07:10: epoch 14 / 30, iter 04080, loss = 0.18  (165.7 images/sec)
# 00:07:11: epoch 14 / 30, iter 04100, loss = 0.17  (165.7 images/sec)
# 00:07:12: epoch 14 / 30, iter 04120, loss = 0.20  (167.0 images/sec)
# 00:07:14: epoch 14 / 30, iter 04140, loss = 0.18  (166.6 images/sec)
# 00:07:15: epoch 14 / 30, iter 04160, loss = 0.24  (166.6 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (548.7 images/sec)
# batch 010 loss = 0.30  (553.8 images/sec)
# batch 020 loss = 0.36  (542.2 images/sec)
# batch 030 loss = 0.18  (546.1 images/sec)
# batch 040 loss = 0.21  (556.8 images/sec)
# [[11618078    43257     9824    24166      215    22191    42891]
#  [   95922  6268360    68668   252044    40664    52150    89048]
#  [   64786   416720   235880   151482     5502    55339    56236]
#  [   78891   259120    40663  5022301    22350    13886    29646]
#  [       1    29595     2337    14028   860522       34      354]
#  [   22959    70091     5910    14756       23   313264    51985]
#  [   93603   150774    12248    50736      239    55578  2192863]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 95.88 %
# 	building IoU accuracy = 79.99 %
# 	infrastructure IoU accuracy = 20.96 %
# 	nature IoU accuracy = 84.07 %
# 	sky IoU accuracy = 88.18 %
# 	person IoU accuracy = 46.19 %
# 	vehicle IoU accuracy = 77.59 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 70.41 %
# Validation pixel accuracy = 91.35 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 70.41 (epoch 14)
#
# Training phase:
# 00:07:30: epoch 15 / 30, iter 04180, loss = 0.23  (167.0 images/sec)
# 00:07:32: epoch 15 / 30, iter 04200, loss = 0.19  (166.6 images/sec)
# 00:07:33: epoch 15 / 30, iter 04220, loss = 0.19  (166.9 images/sec)
# 00:07:34: epoch 15 / 30, iter 04240, loss = 0.20  (171.4 images/sec)
# 00:07:35: epoch 15 / 30, iter 04260, loss = 0.19  (165.8 images/sec)
# 00:07:36: epoch 15 / 30, iter 04280, loss = 0.22  (165.8 images/sec)
# 00:07:38: epoch 15 / 30, iter 04300, loss = 0.20  (166.3 images/sec)
# 00:07:39: epoch 15 / 30, iter 04320, loss = 0.20  (166.5 images/sec)
# 00:07:40: epoch 15 / 30, iter 04340, loss = 0.22  (166.5 images/sec)
# 00:07:41: epoch 15 / 30, iter 04360, loss = 0.19  (167.0 images/sec)
# 00:07:42: epoch 15 / 30, iter 04380, loss = 0.22  (166.0 images/sec)
# 00:07:44: epoch 15 / 30, iter 04400, loss = 0.23  (166.3 images/sec)
# 00:07:45: epoch 15 / 30, iter 04420, loss = 0.19  (166.6 images/sec)
# 00:07:46: epoch 15 / 30, iter 04440, loss = 0.17  (166.3 images/sec)
# 00:07:47: epoch 15 / 30, iter 04460, loss = 0.23  (165.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.30  (557.9 images/sec)
# batch 010 loss = 0.29  (552.3 images/sec)
# batch 020 loss = 0.36  (520.7 images/sec)
# batch 030 loss = 0.18  (507.7 images/sec)
# batch 040 loss = 0.24  (514.7 images/sec)
# [[11556776    35963    23672    30678      233    37444    75856]
#  [   86485  6150414    95569   322435    60770    56336    94847]
#  [   45391   388964   274345   163421     6725    53360    53739]
#  [   73491   200517    40973  5077873    27894    11046    35063]
#  [       1    20193     1853    11164   873514        1      145]
#  [   14321    69177    14052    16865       51   310348    54174]
#  [   45969   136497    24953    45607     1162    59179  2242674]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.10 %
# 	building IoU accuracy = 79.69 %
# 	infrastructure IoU accuracy = 23.11 %
# 	nature IoU accuracy = 83.83 %
# 	sky IoU accuracy = 87.03 %
# 	person IoU accuracy = 44.57 %
# 	vehicle IoU accuracy = 78.15 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 70.35 %
# Validation pixel accuracy = 91.26 %
#
# Best IoU = 70.41 (epoch 14)
#
# Training phase:
# 00:08:02: epoch 16 / 30, iter 04480, loss = 0.22  (167.3 images/sec)
# 00:08:03: epoch 16 / 30, iter 04500, loss = 0.21  (166.4 images/sec)
# 00:08:04: epoch 16 / 30, iter 04520, loss = 0.19  (166.2 images/sec)
# 00:08:05: epoch 16 / 30, iter 04540, loss = 0.15  (166.5 images/sec)
# 00:08:06: epoch 16 / 30, iter 04560, loss = 0.21  (166.6 images/sec)
# 00:08:08: epoch 16 / 30, iter 04580, loss = 0.18  (165.9 images/sec)
# 00:08:09: epoch 16 / 30, iter 04600, loss = 0.17  (164.1 images/sec)
# 00:08:10: epoch 16 / 30, iter 04620, loss = 0.20  (166.7 images/sec)
# 00:08:11: epoch 16 / 30, iter 04640, loss = 0.19  (165.2 images/sec)
# 00:08:13: epoch 16 / 30, iter 04660, loss = 0.21  (166.0 images/sec)
# 00:08:14: epoch 16 / 30, iter 04680, loss = 0.18  (165.7 images/sec)
# 00:08:15: epoch 16 / 30, iter 04700, loss = 0.21  (166.1 images/sec)
# 00:08:16: epoch 16 / 30, iter 04720, loss = 0.20  (165.6 images/sec)
# 00:08:17: epoch 16 / 30, iter 04740, loss = 0.16  (167.3 images/sec)
# 00:08:19: epoch 16 / 30, iter 04760, loss = 0.17  (165.3 images/sec)
#
# Validation phase:
# batch 000 loss = 0.31  (561.7 images/sec)
# batch 010 loss = 0.29  (549.7 images/sec)
# batch 020 loss = 0.36  (554.0 images/sec)
# batch 030 loss = 0.18  (553.0 images/sec)
# batch 040 loss = 0.19  (556.1 images/sec)
# [[11583989    41988    18740    25810      206    22130    67759]
#  [   97190  6221893    81977   261741    49937    64207    89911]
#  [   52388   393177   276702   154565     5919    49341    53853]
#  [   72511   236003    40294  5054453    18383    12981    32232]
#  [       1    23007     1775    17733   863990       39      326]
#  [   19829    51553    10445    14322       18   327978    54843]
#  [   52952   124281    26310    44383      412    56791  2250912]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.09 %
# 	building IoU accuracy = 80.42 %
# 	infrastructure IoU accuracy = 23.74 %
# 	nature IoU accuracy = 84.45 %
# 	sky IoU accuracy = 88.01 %
# 	person IoU accuracy = 47.92 %
# 	vehicle IoU accuracy = 78.84 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 71.35 %
# Validation pixel accuracy = 91.58 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 71.35 (epoch 16)
#
# Training phase:
# 00:08:34: epoch 17 / 30, iter 04780, loss = 0.16  (167.0 images/sec)
# 00:08:35: epoch 17 / 30, iter 04800, loss = 0.18  (167.0 images/sec)
# 00:08:36: epoch 17 / 30, iter 04820, loss = 0.23  (166.3 images/sec)
# 00:08:38: epoch 17 / 30, iter 04840, loss = 0.20  (166.9 images/sec)
# 00:08:39: epoch 17 / 30, iter 04860, loss = 0.17  (166.6 images/sec)
# 00:08:40: epoch 17 / 30, iter 04880, loss = 0.17  (166.5 images/sec)
# 00:08:41: epoch 17 / 30, iter 04900, loss = 0.20  (163.9 images/sec)
# 00:08:42: epoch 17 / 30, iter 04920, loss = 0.17  (166.3 images/sec)
# 00:08:44: epoch 17 / 30, iter 04940, loss = 0.19  (166.1 images/sec)
# 00:08:45: epoch 17 / 30, iter 04960, loss = 0.20  (172.7 images/sec)
# 00:08:46: epoch 17 / 30, iter 04980, loss = 0.21  (166.7 images/sec)
# 00:08:47: epoch 17 / 30, iter 05000, loss = 0.20  (165.3 images/sec)
# 00:08:48: epoch 17 / 30, iter 05020, loss = 0.19  (166.6 images/sec)
# 00:08:50: epoch 17 / 30, iter 05040, loss = 0.20  (165.3 images/sec)
# 00:08:51: epoch 17 / 30, iter 05060, loss = 0.19  (163.8 images/sec)
#
# Validation phase:
# batch 000 loss = 0.28  (545.4 images/sec)
# batch 010 loss = 0.30  (553.3 images/sec)
# batch 020 loss = 0.36  (512.1 images/sec)
# batch 030 loss = 0.18  (516.6 images/sec)
# batch 040 loss = 0.19  (511.9 images/sec)
# [[11572519    63818    14206    35305      215    18648    55911]
#  [   73024  6373982    50570   174585    41175    38667   114853]
#  [   50938   455573   253327   121914     6079    34135    63979]
#  [   64629   319826    46684  4962560    20059    10892    42207]
#  [       1    25433     1490    13998   865433       12      504]
#  [   22903    79665    10446    10215       27   299063    56669]
#  [   80887   129517    13563    33800      237    48015  2250022]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.01 %
# 	building IoU accuracy = 80.27 %
# 	infrastructure IoU accuracy = 22.56 %
# 	nature IoU accuracy = 84.73 %
# 	sky IoU accuracy = 88.79 %
# 	person IoU accuracy = 47.52 %
# 	vehicle IoU accuracy = 77.85 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 71.11 %
# Validation pixel accuracy = 91.57 %
#
# Best IoU = 71.35 (epoch 16)
#
# Training phase:
# 00:09:05: epoch 18 / 30, iter 05080, loss = 0.23  (165.8 images/sec)
# 00:09:06: epoch 18 / 30, iter 05100, loss = 0.17  (166.5 images/sec)
# 00:09:08: epoch 18 / 30, iter 05120, loss = 0.23  (166.7 images/sec)
# 00:09:09: epoch 18 / 30, iter 05140, loss = 0.20  (166.6 images/sec)
# 00:09:10: epoch 18 / 30, iter 05160, loss = 0.16  (166.9 images/sec)
# 00:09:11: epoch 18 / 30, iter 05180, loss = 0.18  (167.3 images/sec)
# 00:09:12: epoch 18 / 30, iter 05200, loss = 0.17  (166.8 images/sec)
# 00:09:14: epoch 18 / 30, iter 05220, loss = 0.18  (165.8 images/sec)
# 00:09:15: epoch 18 / 30, iter 05240, loss = 0.19  (166.5 images/sec)
# 00:09:16: epoch 18 / 30, iter 05260, loss = 0.15  (166.1 images/sec)
# 00:09:17: epoch 18 / 30, iter 05280, loss = 0.16  (166.0 images/sec)
# 00:09:18: epoch 18 / 30, iter 05300, loss = 0.19  (167.2 images/sec)
# 00:09:20: epoch 18 / 30, iter 05320, loss = 0.16  (167.3 images/sec)
# 00:09:21: epoch 18 / 30, iter 05340, loss = 0.19  (165.9 images/sec)
# 00:09:22: epoch 18 / 30, iter 05360, loss = 0.17  (166.4 images/sec)
#
# Validation phase:
# batch 000 loss = 0.28  (497.4 images/sec)
# batch 010 loss = 0.29  (551.7 images/sec)
# batch 020 loss = 0.34  (553.4 images/sec)
# batch 030 loss = 0.17  (544.2 images/sec)
# batch 040 loss = 0.20  (547.8 images/sec)
# [[11539710    52164    25099    41108      202    29725    72614]
#  [   68269  6217153   121388   285825    38251    37456    98514]
#  [   40679   367985   337015   148252     4936    38295    48783]
#  [   54762   206544    54344  5100407    12645     9987    28168]
#  [       1    24841     2371    23163   855557       36      902]
#  [   13744    71673    19333    15813       13   317900    40512]
#  [   40497   126966    26879    47425      253    61989  2252032]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.34 %
# 	building IoU accuracy = 80.56 %
# 	infrastructure IoU accuracy = 27.28 %
# 	nature IoU accuracy = 84.61 %
# 	sky IoU accuracy = 88.83 %
# 	person IoU accuracy = 48.43 %
# 	vehicle IoU accuracy = 79.14 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 72.17 %
# Validation pixel accuracy = 91.72 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 72.17 (epoch 18)
#
# Training phase:
# 00:09:38: epoch 19 / 30, iter 05380, loss = 0.14  (165.4 images/sec)
# 00:09:39: epoch 19 / 30, iter 05400, loss = 0.18  (165.7 images/sec)
# 00:09:40: epoch 19 / 30, iter 05420, loss = 0.21  (165.9 images/sec)
# 00:09:41: epoch 19 / 30, iter 05440, loss = 0.16  (165.7 images/sec)
# 00:09:42: epoch 19 / 30, iter 05460, loss = 0.22  (166.1 images/sec)
# 00:09:44: epoch 19 / 30, iter 05480, loss = 0.13  (165.5 images/sec)
# 00:09:45: epoch 19 / 30, iter 05500, loss = 0.19  (166.7 images/sec)
# 00:09:46: epoch 19 / 30, iter 05520, loss = 0.17  (166.9 images/sec)
# 00:09:47: epoch 19 / 30, iter 05540, loss = 0.20  (165.6 images/sec)
# 00:09:49: epoch 19 / 30, iter 05560, loss = 0.18  (166.9 images/sec)
# 00:09:50: epoch 19 / 30, iter 05580, loss = 0.17  (167.1 images/sec)
# 00:09:51: epoch 19 / 30, iter 05600, loss = 0.15  (164.6 images/sec)
# 00:09:52: epoch 19 / 30, iter 05620, loss = 0.15  (171.7 images/sec)
# 00:09:53: epoch 19 / 30, iter 05640, loss = 0.18  (166.0 images/sec)
# 00:09:55: epoch 19 / 30, iter 05660, loss = 0.23  (167.2 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (554.1 images/sec)
# batch 010 loss = 0.30  (554.0 images/sec)
# batch 020 loss = 0.35  (510.5 images/sec)
# batch 030 loss = 0.18  (513.0 images/sec)
# batch 040 loss = 0.20  (515.1 images/sec)
# [[11574519    51821    28459    24181      221    30270    51151]
#  [   72819  6295455   118712   184554    50218    49627    95471]
#  [   44491   399986   331780   114706     5945    44236    44801]
#  [   71349   287317    81334  4959274    20572    16228    30783]
#  [       1    22993     2185    14700   866458        4      530]
#  [   15339    66086    16529     9813       25   336857    34339]
#  [   63163   131840    31908    31165      567    74303  2223095]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.23 %
# 	building IoU accuracy = 80.43 %
# 	infrastructure IoU accuracy = 26.23 %
# 	nature IoU accuracy = 84.83 %
# 	sky IoU accuracy = 88.02 %
# 	person IoU accuracy = 48.56 %
# 	vehicle IoU accuracy = 79.03 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 71.90 %
# Validation pixel accuracy = 91.61 %
#
# Best IoU = 72.17 (epoch 18)
#
# Training phase:
# 00:10:09: epoch 20 / 30, iter 05680, loss = 0.20  (166.8 images/sec)
# 00:10:10: epoch 20 / 30, iter 05700, loss = 0.16  (166.2 images/sec)
# 00:10:11: epoch 20 / 30, iter 05720, loss = 0.17  (167.0 images/sec)
# 00:10:13: epoch 20 / 30, iter 05740, loss = 0.20  (166.6 images/sec)
# 00:10:14: epoch 20 / 30, iter 05760, loss = 0.15  (165.4 images/sec)
# 00:10:15: epoch 20 / 30, iter 05780, loss = 0.15  (165.7 images/sec)
# 00:10:16: epoch 20 / 30, iter 05800, loss = 0.21  (166.7 images/sec)
# 00:10:17: epoch 20 / 30, iter 05820, loss = 0.21  (171.6 images/sec)
# 00:10:19: epoch 20 / 30, iter 05840, loss = 0.19  (165.9 images/sec)
# 00:10:20: epoch 20 / 30, iter 05860, loss = 0.19  (166.3 images/sec)
# 00:10:21: epoch 20 / 30, iter 05880, loss = 0.16  (164.8 images/sec)
# 00:10:22: epoch 20 / 30, iter 05900, loss = 0.14  (166.5 images/sec)
# 00:10:23: epoch 20 / 30, iter 05920, loss = 0.16  (166.3 images/sec)
# 00:10:25: epoch 20 / 30, iter 05940, loss = 0.20  (166.1 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (534.9 images/sec)
# batch 010 loss = 0.29  (546.0 images/sec)
# batch 020 loss = 0.34  (552.2 images/sec)
# batch 030 loss = 0.17  (546.6 images/sec)
# batch 040 loss = 0.19  (547.1 images/sec)
# [[11550831    61394    18243    31615      208    21743    76588]
#  [   67963  6336635   109519   190307    33689    34497    94246]
#  [   45967   397397   338950   114852     4726    32808    51245]
#  [   66700   274010    78095  4983758    19645    10455    34194]
#  [       1    32356     3092    13813   856547        4     1058]
#  [   18297    74197    14151    11881       23   310681    49758]
#  [   43446   131670    23390    35177      267    46193  2275898]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.23 %
# 	building IoU accuracy = 80.85 %
# 	infrastructure IoU accuracy = 27.50 %
# 	nature IoU accuracy = 84.98 %
# 	sky IoU accuracy = 88.72 %
# 	person IoU accuracy = 49.73 %
# 	vehicle IoU accuracy = 79.49 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 72.50 %
# Validation pixel accuracy = 91.84 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 72.50 (epoch 20)
#
# Training phase:
# 00:10:40: epoch 21 / 30, iter 05960, loss = 0.17  (165.6 images/sec)
# 00:10:41: epoch 21 / 30, iter 05980, loss = 0.18  (166.3 images/sec)
# 00:10:42: epoch 21 / 30, iter 06000, loss = 0.14  (166.2 images/sec)
# 00:10:44: epoch 21 / 30, iter 06020, loss = 0.15  (169.8 images/sec)
# 00:10:45: epoch 21 / 30, iter 06040, loss = 0.14  (164.7 images/sec)
# 00:10:46: epoch 21 / 30, iter 06060, loss = 0.15  (167.6 images/sec)
# 00:10:47: epoch 21 / 30, iter 06080, loss = 0.14  (166.5 images/sec)
# 00:10:48: epoch 21 / 30, iter 06100, loss = 0.18  (165.7 images/sec)
# 00:10:50: epoch 21 / 30, iter 06120, loss = 0.16  (166.3 images/sec)
# 00:10:51: epoch 21 / 30, iter 06140, loss = 0.16  (165.9 images/sec)
# 00:10:52: epoch 21 / 30, iter 06160, loss = 0.17  (166.1 images/sec)
# 00:10:53: epoch 21 / 30, iter 06180, loss = 0.16  (166.3 images/sec)
# 00:10:54: epoch 21 / 30, iter 06200, loss = 0.17  (171.7 images/sec)
# 00:10:56: epoch 21 / 30, iter 06220, loss = 0.19  (165.3 images/sec)
# 00:10:57: epoch 21 / 30, iter 06240, loss = 0.11  (164.7 images/sec)
#
# Validation phase:
# batch 000 loss = 0.28  (552.2 images/sec)
# batch 010 loss = 0.29  (551.1 images/sec)
# batch 020 loss = 0.34  (509.9 images/sec)
# batch 030 loss = 0.17  (519.3 images/sec)
# batch 040 loss = 0.19  (517.7 images/sec)
# [[11575915    44536    22199    20535      223    25479    71735]
#  [   83061  6223953   122112   226515    41071    49154   120990]
#  [   44922   362552   337059   132122     6044    40671    62575]
#  [   85373   233489    48933  5029997    19901    11945    37219]
#  [       1    27954     1450    14129   862444       16      877]
#  [   14997    54323    13263    12808       21   332030    51546]
#  [   43023    95614    20594    34700     1314    48220  2312576]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.21 %
# 	building IoU accuracy = 80.98 %
# 	infrastructure IoU accuracy = 27.75 %
# 	nature IoU accuracy = 85.14 %
# 	sky IoU accuracy = 88.42 %
# 	person IoU accuracy = 50.73 %
# 	vehicle IoU accuracy = 79.72 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 72.71 %
# Validation pixel accuracy = 91.91 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 72.71 (epoch 21)
#
# Training phase:
# 00:11:12: epoch 22 / 30, iter 06260, loss = 0.14  (149.9 images/sec)
# 00:11:14: epoch 22 / 30, iter 06280, loss = 0.17  (167.5 images/sec)
# 00:11:15: epoch 22 / 30, iter 06300, loss = 0.15  (164.5 images/sec)
# 00:11:16: epoch 22 / 30, iter 06320, loss = 0.13  (167.2 images/sec)
# 00:11:17: epoch 22 / 30, iter 06340, loss = 0.17  (165.9 images/sec)
# 00:11:18: epoch 22 / 30, iter 06360, loss = 0.15  (166.4 images/sec)
# 00:11:20: epoch 22 / 30, iter 06380, loss = 0.13  (166.7 images/sec)
# 00:11:21: epoch 22 / 30, iter 06400, loss = 0.17  (167.4 images/sec)
# 00:11:22: epoch 22 / 30, iter 06420, loss = 0.14  (164.9 images/sec)
# 00:11:23: epoch 22 / 30, iter 06440, loss = 0.15  (171.2 images/sec)
# 00:11:24: epoch 22 / 30, iter 06460, loss = 0.18  (166.4 images/sec)
# 00:11:26: epoch 22 / 30, iter 06480, loss = 0.14  (165.8 images/sec)
# 00:11:27: epoch 22 / 30, iter 06500, loss = 0.15  (166.3 images/sec)
# 00:11:28: epoch 22 / 30, iter 06520, loss = 0.15  (163.4 images/sec)
# 00:11:29: epoch 22 / 30, iter 06540, loss = 0.18  (166.1 images/sec)
#
# Validation phase:
# batch 000 loss = 0.27  (552.5 images/sec)
# batch 010 loss = 0.30  (554.3 images/sec)
# batch 020 loss = 0.33  (552.5 images/sec)
# batch 030 loss = 0.17  (543.0 images/sec)
# batch 040 loss = 0.19  (539.7 images/sec)
# [[11571425    40752    22637    26910      219    28164    70515]
#  [   78269  6282815   109014   219272    46632    39923    90931]
#  [   42162   380780   334334   133980     5961    34492    54236]
#  [   71196   244897    48908  5039183    20539     9350    32784]
#  [       1    23634     1802    14016   866960        9      449]
#  [   13748    62141    15448    13535       27   323718    50371]
#  [   44609   123368    24044    38254     1602    49234  2274930]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.34 %
# 	building IoU accuracy = 81.15 %
# 	infrastructure IoU accuracy = 27.68 %
# 	nature IoU accuracy = 85.22 %
# 	sky IoU accuracy = 88.30 %
# 	person IoU accuracy = 50.57 %
# 	vehicle IoU accuracy = 79.67 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 72.71 %
# Validation pixel accuracy = 91.98 %
#
# Best IoU = 72.71 (epoch 21)
#
# Training phase:
# 00:11:44: epoch 23 / 30, iter 06560, loss = 0.17  (167.4 images/sec)
# 00:11:45: epoch 23 / 30, iter 06580, loss = 0.17  (166.4 images/sec)
# 00:11:46: epoch 23 / 30, iter 06600, loss = 0.14  (165.1 images/sec)
# 00:11:47: epoch 23 / 30, iter 06620, loss = 0.14  (165.3 images/sec)
# ...
# batch 030 loss = 0.17  (516.0 images/sec)
# batch 040 loss = 0.19  (516.5 images/sec)
# [[11584028    39693    25121    23395      239    21687    66459]
#  [   84580  6300109   110489   202873    43762    30002    95041]
#  [   43372   383281   346685   122927     6277    28301    55102]
#  [   77557   256647    59565  5003343    26063     7960    35722]
#  [       1    25375     1875    10339   868756       13      512]
#  [   16647    72109    17744    12862       34   304513    55079]
#  [   49598   120960    22978    35934      821    37617  2288133]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.27 %
# 	building IoU accuracy = 81.14 %
# 	infrastructure IoU accuracy = 28.33 %
# 	nature IoU accuracy = 85.16 %
# 	sky IoU accuracy = 88.28 %
# 	person IoU accuracy = 50.37 %
# 	vehicle IoU accuracy = 79.89 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 72.78 %
# Validation pixel accuracy = 91.98 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 72.78 (epoch 23)
#
# Training phase:
# 00:12:16: epoch 24 / 30, iter 06860, loss = 0.14  (161.4 images/sec)
# 00:12:17: epoch 24 / 30, iter 06880, loss = 0.16  (165.0 images/sec)
# 00:12:19: epoch 24 / 30, iter 06900, loss = 0.16  (165.9 images/sec)
# 00:12:20: epoch 24 / 30, iter 06920, loss = 0.13  (165.5 images/sec)
# 00:12:21: epoch 24 / 30, iter 06940, loss = 0.13  (165.9 images/sec)
# 00:12:22: epoch 24 / 30, iter 06960, loss = 0.13  (166.5 images/sec)
# 00:12:23: epoch 24 / 30, iter 06980, loss = 0.16  (165.5 images/sec)
# 00:12:25: epoch 24 / 30, iter 07000, loss = 0.14  (165.7 images/sec)
# 00:12:26: epoch 24 / 30, iter 07020, loss = 0.12  (164.9 images/sec)
# 00:12:27: epoch 24 / 30, iter 07040, loss = 0.13  (167.7 images/sec)
# 00:12:28: epoch 24 / 30, iter 07060, loss = 0.18  (166.7 images/sec)
# 00:12:29: epoch 24 / 30, iter 07080, loss = 0.13  (165.5 images/sec)
# 00:12:31: epoch 24 / 30, iter 07100, loss = 0.13  (165.6 images/sec)
# 00:12:32: epoch 24 / 30, iter 07120, loss = 0.15  (166.3 images/sec)
# 00:12:33: epoch 24 / 30, iter 07140, loss = 0.17  (166.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.28  (553.2 images/sec)
# batch 010 loss = 0.29  (547.4 images/sec)
# batch 020 loss = 0.35  (545.7 images/sec)
# batch 030 loss = 0.17  (546.2 images/sec)
# batch 040 loss = 0.19  (553.3 images/sec)
# [[11572247    40197    30541    23786      219    25911    67721]
#  [   74797  6227179   159477   199468    45784    50712   109439]
#  [   40489   347114   386439   110731     5466    38053    57653]
#  [   73280   249102    74301  4997695    17067    14424    40988]
#  [       1    21626     2230    17165   865195       27      627]
#  [   14978    50393    15165     9723       23   340823    47883]
#  [   45022   104560    25934    28983     1788    51557  2298197]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.36 %
# 	building IoU accuracy = 81.08 %
# 	infrastructure IoU accuracy = 29.87 %
# 	nature IoU accuracy = 85.33 %
# 	sky IoU accuracy = 88.54 %
# 	person IoU accuracy = 51.67 %
# 	vehicle IoU accuracy = 79.79 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 73.23 %
# Validation pixel accuracy = 91.96 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 73.23 (epoch 24)
#
# Training phase:
# 00:12:49: epoch 25 / 30, iter 07160, loss = 0.15  (167.7 images/sec)
# 00:12:50: epoch 25 / 30, iter 07180, loss = 0.16  (167.2 images/sec)
# 00:12:51: epoch 25 / 30, iter 07200, loss = 0.14  (165.6 images/sec)
# 00:12:52: epoch 25 / 30, iter 07220, loss = 0.18  (166.1 images/sec)
# 00:12:53: epoch 25 / 30, iter 07240, loss = 0.17  (166.7 images/sec)
# 00:12:55: epoch 25 / 30, iter 07260, loss = 0.15  (166.6 images/sec)
# 00:12:56: epoch 25 / 30, iter 07280, loss = 0.16  (166.4 images/sec)
# 00:12:57: epoch 25 / 30, iter 07300, loss = 0.15  (166.2 images/sec)
# 00:12:58: epoch 25 / 30, iter 07320, loss = 0.13  (165.4 images/sec)
# 00:12:59: epoch 25 / 30, iter 07340, loss = 0.13  (164.6 images/sec)
# 00:13:01: epoch 25 / 30, iter 07360, loss = 0.16  (166.4 images/sec)
# 00:13:02: epoch 25 / 30, iter 07380, loss = 0.14  (166.8 images/sec)
# 00:13:03: epoch 25 / 30, iter 07400, loss = 0.16  (166.7 images/sec)
# 00:13:04: epoch 25 / 30, iter 07420, loss = 0.13  (166.5 images/sec)
# 00:13:05: epoch 25 / 30, iter 07440, loss = 0.13  (166.0 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (554.8 images/sec)
# batch 010 loss = 0.29  (549.3 images/sec)
# batch 020 loss = 0.35  (508.3 images/sec)
# batch 030 loss = 0.17  (513.2 images/sec)
# batch 040 loss = 0.19  (514.9 images/sec)
# [[11555062    51869    30514    23385      219    29930    69643]
#  [   67535  6291197   132810   202880    39486    35949    96999]
#  [   37612   369135   374505   117792     5035    31336    50530]
#  [   72028   249591    75550  5003619    20647    11454    33968]
#  [       1    27549     2499    13120   862848       45      809]
#  [   12496    65875    18865    11492       29   327404    42827]
#  [   42901   114777    28637    33792      333    51821  2283780]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.35 %
# 	building IoU accuracy = 81.22 %
# 	infrastructure IoU accuracy = 29.38 %
# 	nature IoU accuracy = 85.25 %
# 	sky IoU accuracy = 88.71 %
# 	person IoU accuracy = 51.20 %
# 	vehicle IoU accuracy = 80.11 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 73.17 %
# Validation pixel accuracy = 91.99 %
#
# Best IoU = 73.23 (epoch 24)
#
# Training phase:
# 00:13:20: epoch 26 / 30, iter 07460, loss = 0.14  (167.8 images/sec)
# 00:13:21: epoch 26 / 30, iter 07480, loss = 0.14  (166.1 images/sec)
# 00:13:22: epoch 26 / 30, iter 07500, loss = 0.14  (165.0 images/sec)
# 00:13:23: epoch 26 / 30, iter 07520, loss = 0.12  (166.3 images/sec)
# 00:13:25: epoch 26 / 30, iter 07540, loss = 0.14  (165.4 images/sec)
# 00:13:26: epoch 26 / 30, iter 07560, loss = 0.13  (166.8 images/sec)
# 00:13:27: epoch 26 / 30, iter 07580, loss = 0.16  (165.6 images/sec)
# 00:13:28: epoch 26 / 30, iter 07600, loss = 0.13  (166.9 images/sec)
# 00:13:29: epoch 26 / 30, iter 07620, loss = 0.13  (166.3 images/sec)
# 00:13:31: epoch 26 / 30, iter 07640, loss = 0.14  (167.7 images/sec)
# 00:13:32: epoch 26 / 30, iter 07660, loss = 0.12  (165.6 images/sec)
# 00:13:33: epoch 26 / 30, iter 07680, loss = 0.13  (167.0 images/sec)
# 00:13:34: epoch 26 / 30, iter 07700, loss = 0.13  (166.0 images/sec)
# 00:13:35: epoch 26 / 30, iter 07720, loss = 0.14  (166.0 images/sec)
# 00:13:37: epoch 26 / 30, iter 07740, loss = 0.15  (171.3 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (550.0 images/sec)
# batch 010 loss = 0.30  (554.6 images/sec)
# batch 020 loss = 0.36  (551.1 images/sec)
# batch 030 loss = 0.17  (547.7 images/sec)
# batch 040 loss = 0.19  (552.3 images/sec)
# [[11578472    43696    21360    24531      220    25504    66839]
#  [   74958  6214390   115078   262037    48041    42414   109938]
#  [   44111   361308   339482   139367     5917    36697    59063]
#  [   76193   207065    48503  5068321    16823    11030    38922]
#  [       1    20359     1700    17506   866620       12      673]
#  [   14778    57474    12195    13073       23   330584    50861]
#  [   46216   102281    17799    35070      432    46729  2307514]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.35 %
# 	building IoU accuracy = 81.14 %
# 	infrastructure IoU accuracy = 28.23 %
# 	nature IoU accuracy = 85.06 %
# 	sky IoU accuracy = 88.58 %
# 	person IoU accuracy = 51.54 %
# 	vehicle IoU accuracy = 80.06 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 72.99 %
# Validation pixel accuracy = 92.02 %
#
# Best IoU = 73.23 (epoch 24)
#
# Training phase:
# 00:13:51: epoch 27 / 30, iter 07760, loss = 0.13  (166.5 images/sec)
# 00:13:52: epoch 27 / 30, iter 07780, loss = 0.14  (165.8 images/sec)
# 00:13:54: epoch 27 / 30, iter 07800, loss = 0.14  (166.4 images/sec)
# 00:13:55: epoch 27 / 30, iter 07820, loss = 0.16  (165.1 images/sec)
# 00:13:56: epoch 27 / 30, iter 07840, loss = 0.14  (164.6 images/sec)
# 00:13:57: epoch 27 / 30, iter 07860, loss = 0.13  (166.1 images/sec)
# 00:13:58: epoch 27 / 30, iter 07880, loss = 0.13  (165.7 images/sec)
# 00:14:00: epoch 27 / 30, iter 07900, loss = 0.13  (159.9 images/sec)
# 00:14:01: epoch 27 / 30, iter 07920, loss = 0.14  (165.3 images/sec)
# 00:14:02: epoch 27 / 30, iter 07940, loss = 0.14  (165.6 images/sec)
# 00:14:03: epoch 27 / 30, iter 07960, loss = 0.13  (167.1 images/sec)
# 00:14:04: epoch 27 / 30, iter 07980, loss = 0.13  (160.4 images/sec)
# 00:14:06: epoch 27 / 30, iter 08000, loss = 0.16  (166.4 images/sec)
# 00:14:07: epoch 27 / 30, iter 08020, loss = 0.16  (166.1 images/sec)
# 00:14:08: epoch 27 / 30, iter 08040, loss = 0.13  (165.6 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (551.4 images/sec)
# batch 010 loss = 0.30  (547.6 images/sec)
# batch 020 loss = 0.36  (518.3 images/sec)
# batch 030 loss = 0.17  (504.3 images/sec)
# batch 040 loss = 0.21  (507.6 images/sec)
# [[11592278    39690    20678    27284      227    24370    56095]
#  [   82092  6243107   107564   242373    42798    48080   100842]
#  [   45142   368509   337206   136599     6144    38686    53659]
#  [   74669   225557    44888  5054948    20197    13088    33510]
#  [       1    24173     1685    13617   866952       29      414]
#  [   15926    54193    11541    12481       27   342221    42599]
#  [   55168   103118    17724    37743     1007    55636  2285645]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.33 %
# 	building IoU accuracy = 81.27 %
# 	infrastructure IoU accuracy = 28.34 %
# 	nature IoU accuracy = 85.14 %
# 	sky IoU accuracy = 88.71 %
# 	person IoU accuracy = 51.94 %
# 	vehicle IoU accuracy = 80.39 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 73.16 %
# Validation pixel accuracy = 92.08 %
#
# Best IoU = 73.23 (epoch 24)
#
# Training phase:
# 00:14:22: epoch 28 / 30, iter 08060, loss = 0.14  (165.9 images/sec)
# 00:14:24: epoch 28 / 30, iter 08080, loss = 0.12  (165.7 images/sec)
# 00:14:25: epoch 28 / 30, iter 08100, loss = 0.13  (166.6 images/sec)
# 00:14:26: epoch 28 / 30, iter 08120, loss = 0.12  (165.9 images/sec)
# 00:14:27: epoch 28 / 30, iter 08140, loss = 0.16  (166.8 images/sec)
# 00:14:28: epoch 28 / 30, iter 08160, loss = 0.14  (165.7 images/sec)
# 00:14:30: epoch 28 / 30, iter 08180, loss = 0.14  (172.5 images/sec)
# 00:14:31: epoch 28 / 30, iter 08200, loss = 0.13  (164.8 images/sec)
# 00:14:32: epoch 28 / 30, iter 08220, loss = 0.16  (165.3 images/sec)
# 00:14:33: epoch 28 / 30, iter 08240, loss = 0.19  (166.6 images/sec)
# 00:14:35: epoch 28 / 30, iter 08260, loss = 0.13  (160.1 images/sec)
# 00:14:36: epoch 28 / 30, iter 08280, loss = 0.14  (166.1 images/sec)
# 00:14:37: epoch 28 / 30, iter 08300, loss = 0.18  (170.6 images/sec)
# 00:14:38: epoch 28 / 30, iter 08320, loss = 0.15  (165.8 images/sec)
# 00:14:39: epoch 28 / 30, iter 08340, loss = 0.11  (166.4 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (540.5 images/sec)
# batch 010 loss = 0.31  (551.8 images/sec)
# batch 020 loss = 0.35  (556.0 images/sec)
# batch 030 loss = 0.17  (547.4 images/sec)
# batch 040 loss = 0.19  (556.7 images/sec)
# [[11588741    42368    22402    26039      224    21492    59356]
#  [   77002  6260037   127291   219943    44112    38615    99856]
#  [   43424   364564   362633   125702     5645    31295    52682]
#  [   76378   236678    55582  5031903    19920    10931    35465]
#  [       1    23783     2130    14004   866369       28      556]
#  [   16652    60376    15372    11833       26   329442    45287]
#  [   52745   108873    21420    34205      900    47054  2290844]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.36 %
# 	building IoU accuracy = 81.26 %
# 	infrastructure IoU accuracy = 29.48 %
# 	nature IoU accuracy = 85.31 %
# 	sky IoU accuracy = 88.61 %
# 	person IoU accuracy = 52.43 %
# 	vehicle IoU accuracy = 80.40 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 73.41 %
# Validation pixel accuracy = 92.10 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 73.41 (epoch 28)
#
# Training phase:
# 00:14:55: epoch 29 / 30, iter 08360, loss = 0.14  (166.4 images/sec)
# 00:14:56: epoch 29 / 30, iter 08380, loss = 0.17  (166.5 images/sec)
# 00:14:57: epoch 29 / 30, iter 08400, loss = 0.14  (165.2 images/sec)
# 00:14:58: epoch 29 / 30, iter 08420, loss = 0.14  (166.3 images/sec)
# 00:15:00: epoch 29 / 30, iter 08440, loss = 0.14  (165.9 images/sec)
# 00:15:01: epoch 29 / 30, iter 08460, loss = 0.14  (166.7 images/sec)
# 00:15:02: epoch 29 / 30, iter 08480, loss = 0.13  (166.0 images/sec)
# 00:15:03: epoch 29 / 30, iter 08500, loss = 0.16  (166.4 images/sec)
# 00:15:04: epoch 29 / 30, iter 08520, loss = 0.13  (165.6 images/sec)
# 00:15:06: epoch 29 / 30, iter 08540, loss = 0.12  (165.9 images/sec)
# 00:15:07: epoch 29 / 30, iter 08560, loss = 0.14  (164.6 images/sec)
# 00:15:08: epoch 29 / 30, iter 08580, loss = 0.14  (165.6 images/sec)
# 00:15:09: epoch 29 / 30, iter 08600, loss = 0.12  (166.7 images/sec)
# 00:15:10: epoch 29 / 30, iter 08620, loss = 0.17  (164.4 images/sec)
# 00:15:12: epoch 29 / 30, iter 08640, loss = 0.14  (165.5 images/sec)
#
# Validation phase:
# batch 000 loss = 0.29  (556.2 images/sec)
# batch 010 loss = 0.31  (551.8 images/sec)
# batch 020 loss = 0.36  (513.2 images/sec)
# batch 030 loss = 0.17  (515.7 images/sec)
# batch 040 loss = 0.20  (508.4 images/sec)
# [[11599832    36894    20451    25808      222    20835    56580]
#  [   85218  6242039   124967   224216    42794    44623   102999]
#  [   46542   359161   356135   126524     5537    35300    56746]
#  [   78034   235223    51808  5032540    18583    12143    38526]
#  [       1    24888     2069    14891   864530       23      469]
#  [   18165    54703    13028    11650       26   335101    46315]
#  [   55005   103595    19362    32811      943    47942  2296383]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.32 %
# 	building IoU accuracy = 81.26 %
# 	infrastructure IoU accuracy = 29.25 %
# 	nature IoU accuracy = 85.26 %
# 	sky IoU accuracy = 88.67 %
# 	person IoU accuracy = 52.37 %
# 	vehicle IoU accuracy = 80.36 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 73.36 %
# Validation pixel accuracy = 92.09 %
#
# Best IoU = 73.41 (epoch 28)
#
# Training phase:
# 00:15:26: epoch 30 / 30, iter 08660, loss = 0.14  (166.9 images/sec)
# 00:15:27: epoch 30 / 30, iter 08680, loss = 0.13  (167.7 images/sec)
# 00:15:28: epoch 30 / 30, iter 08700, loss = 0.12  (166.5 images/sec)
# 00:15:30: epoch 30 / 30, iter 08720, loss = 0.10  (166.6 images/sec)
# 00:15:31: epoch 30 / 30, iter 08740, loss = 0.14  (166.1 images/sec)
# 00:15:32: epoch 30 / 30, iter 08760, loss = 0.13  (167.9 images/sec)
# 00:15:33: epoch 30 / 30, iter 08780, loss = 0.11  (166.3 images/sec)
# 00:15:34: epoch 30 / 30, iter 08800, loss = 0.12  (173.0 images/sec)
# 00:15:36: epoch 30 / 30, iter 08820, loss = 0.12  (165.7 images/sec)
# 00:15:37: epoch 30 / 30, iter 08840, loss = 0.13  (165.6 images/sec)
# 00:15:38: epoch 30 / 30, iter 08860, loss = 0.17  (166.7 images/sec)
# 00:15:39: epoch 30 / 30, iter 08880, loss = 0.13  (165.6 images/sec)
# 00:15:40: epoch 30 / 30, iter 08900, loss = 0.12  (165.6 images/sec)
# 00:15:42: epoch 30 / 30, iter 08920, loss = 0.14  (166.2 images/sec)
#
# Validation phase:
# batch 000 loss = 0.30  (552.4 images/sec)
# batch 010 loss = 0.31  (545.5 images/sec)
# batch 020 loss = 0.36  (546.3 images/sec)
# batch 030 loss = 0.17  (545.7 images/sec)
# batch 040 loss = 0.19  (552.1 images/sec)
# [[11582920    40941    25816    26418      222    22453    61852]
#  [   77441  6246505   138818   218758    44557    40271   100506]
#  [   42025   356662   373558   122759     5554    31484    53903]
#  [   75027   237562    60562  5027027    18976    11137    36566]
#  [       1    24017     2180    14694   865468       22      489]
#  [   16129    57830    16246    11762       26   331218    45777]
#  [   48792   104950    23402    33469      897    47395  2297136]]
#
#  Validation  evaluation metrics:
# 	road IoU accuracy = 96.36 %
# 	building IoU accuracy = 81.24 %
# 	infrastructure IoU accuracy = 29.81 %
# 	nature IoU accuracy = 85.28 %
# 	sky IoU accuracy = 88.57 %
# 	person IoU accuracy = 52.43 %
# 	vehicle IoU accuracy = 80.46 %
# Validation IoU mean class accuracy - TP / (TP+FN+FP) = 73.45 %
# Validation pixel accuracy = 92.08 %
# Model saved in file:  local/checkpoint2/model.ckpt
#
# Best IoU = 73.45 (epoch 30)

# %%
# restore the best checkpoint
checkpoint_path = 'local/pretrained2/model.ckpt'
saver = tf.train.Saver()
saver.restore(sess, checkpoint_path)
validate(sess, val_data, x, y, y_pred, loss, draw_steps=10)

# %% [markdown]
# ## Train with batch norm

# %% [markdown]
# ## 5. Homework
#
# If you wish you can play with the model. Try to improve on the current IoU.
